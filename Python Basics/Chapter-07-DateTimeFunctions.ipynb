# %% [markdown]
# # Datetime
#
# Python has the datetime module to help deal with timestamps in your code. Time values are represented with the time class. Times have attributes for hour, minute, second, and microsecond. They can also include time zone information. The arguments to initialize a time instance are optional, but the default of 0 is unlikely to be what you want.

# %% [markdown]
# ##### datetime class
# ##### time class
# ##### date class
# ##### timedelta class
# ##### timezone class
# ##### tzinfo class

# %% [markdown]
# ## Time
# Let's take a look at how we can extract time information from the datetime module. We can create a timestamp by specifying datetime.time(hour,minute,second,microsecond)

# %%
import datetime
from pytz import timezone

timedefault = datetime.time()
print(timedefault)
print("#########################")
t = datetime.time(4, 20, 1,123456)
print(t)
print(t.tzinfo)
print("#########################")
utctime = datetime.time(4, 20, 1,123456, timezone('UTC'))
print(utctime.tzinfo)
print("#########################")
Austime = datetime.time(4, 20, 1,123456, timezone('Australia/Sydney'))
print(Austime.tzinfo)
print("#########################")
Ustime = datetime.time(4, 20, 1,123456, timezone('America/St_Johns'))
print(Ustime.tzinfo)

# Let's show the different components
print(timedefault)
print(timedefault.tzinfo)
print("######################################")
print(t)
print("######################################")
print(utctime)
print("######################################")
print(Austime)
print("######################################")
print(Ustime)
print("######################################")

print('hour  :', utctime.hour)
print('minute:', utctime.minute)
print('second:', utctime.second)
print('microsecond:', utctime.microsecond)
print('tzinfo:', utctime.tzinfo)
# Out:
# 00:00:00
# #########################
# 04:20:01.123456
# None
# #########################
# UTC
# #########################
# Australia/Sydney
# #########################
# America/St_Johns
# 00:00:00
# None
# ######################################
# 04:20:01.123456
# ######################################
# 04:20:01.123456+00:00
# ######################################
# 04:20:01.123456
# ######################################
# 04:20:01.123456
# ######################################
# hour  : 4
# minute: 20
# second: 1
# microsecond: 123456
# tzinfo: UTC

# %% [markdown]
# ##### Get all timezones

# %%
from pytz import all_timezones
print(type(all_timezones))
print(list(all_timezones))
# Out:
# <class 'pytz.lazy.LazyList.__new__.<locals>.LazyList'>
# ['Africa/Abidjan', 'Africa/Accra', 'Africa/Addis_Ababa', 'Africa/Algiers', 'Africa/Asmara', 'Africa/Asmera', 'Africa/Bamako', 'Africa/Bangui', 'Africa/Banjul', 'Africa/Bissau', 'Africa/Blantyre', 'Africa/Brazzaville', 'Africa/Bujumbura', 'Africa/Cairo', 'Africa/Casablanca', 'Africa/Ceuta', 'Africa/Conakry', 'Africa/Dakar', 'Africa/Dar_es_Salaam', 'Africa/Djibouti', 'Africa/Douala', 'Africa/El_Aaiun', 'Africa/Freetown', 'Africa/Gaborone', 'Africa/Harare', 'Africa/Johannesburg', 'Africa/Juba', 'Africa/Kampala', 'Africa/Khartoum', 'Africa/Kigali', 'Africa/Kinshasa', 'Africa/Lagos', 'Africa/Libreville', 'Africa/Lome', 'Africa/Luanda', 'Africa/Lubumbashi', 'Africa/Lusaka', 'Africa/Malabo', 'Africa/Maputo', 'Africa/Maseru', 'Africa/Mbabane', 'Africa/Mogadishu', 'Africa/Monrovia', 'Africa/Nairobi', 'Africa/Ndjamena', 'Africa/Niamey', 'Africa/Nouakchott', 'Africa/Ouagadougou', 'Africa/Porto-Novo', 'Africa/Sao_Tome', 'Africa/Timbuktu', 'Africa/Tripoli', 'Africa/Tunis', 'Africa/Windhoek', 'America/Adak', 'America/Anchorage', 'America/Anguilla', 'America/Antigua', 'America/Araguaina', 'America/Argentina/Buenos_Aires', 'America/Argentina/Catamarca', 'America/Argentina/ComodRivadavia', 'America/Argentina/Cordoba', 'America/Argentina/Jujuy', 'America/Argentina/La_Rioja', 'America/Argentina/Mendoza', 'America/Argentina/Rio_Gallegos', 'America/Argentina/Salta', 'America/Argentina/San_Juan', 'America/Argentina/San_Luis', 'America/Argentina/Tucuman', 'America/Argentina/Ushuaia', 'America/Aruba', 'America/Asuncion', 'America/Atikokan', 'America/Atka', 'America/Bahia', 'America/Bahia_Banderas', 'America/Barbados', 'America/Belem', 'America/Belize', 'America/Blanc-Sablon', 'America/Boa_Vista', 'America/Bogota', 'America/Boise', 'America/Buenos_Aires', 'America/Cambridge_Bay', 'America/Campo_Grande', 'America/Cancun', 'America/Caracas', 'America/Catamarca', 'America/Cayenne', 'America/Cayman', 'America/Chicago', 'America/Chihuahua', 'America/Coral_Harbour', 'America/Cordoba', 'America/Costa_Rica', 'America/Creston', 'America/Cuiaba', 'America/Curacao', 'America/Danmarkshavn', 'America/Dawson', 'America/Dawson_Creek', 'America/Denver', 'America/Detroit', 'America/Dominica', 'America/Edmonton', 'America/Eirunepe', 'America/El_Salvador', 'America/Ensenada', 'America/Fort_Nelson', 'America/Fort_Wayne', 'America/Fortaleza', 'America/Glace_Bay', 'America/Godthab', 'America/Goose_Bay', 'America/Grand_Turk', 'America/Grenada', 'America/Guadeloupe', 'America/Guatemala', 'America/Guayaquil', 'America/Guyana', 'America/Halifax', 'America/Havana', 'America/Hermosillo', 'America/Indiana/Indianapolis', 'America/Indiana/Knox', 'America/Indiana/Marengo', 'America/Indiana/Petersburg', 'America/Indiana/Tell_City', 'America/Indiana/Vevay', 'America/Indiana/Vincennes', 'America/Indiana/Winamac', 'America/Indianapolis', 'America/Inuvik', 'America/Iqaluit', 'America/Jamaica', 'America/Jujuy', 'America/Juneau', 'America/Kentucky/Louisville', 'America/Kentucky/Monticello', 'America/Knox_IN', 'America/Kralendijk', 'America/La_Paz', 'America/Lima', 'America/Los_Angeles', 'America/Louisville', 'America/Lower_Princes', 'America/Maceio', 'America/Managua', 'America/Manaus', 'America/Marigot', 'America/Martinique', 'America/Matamoros', 'America/Mazatlan', 'America/Mendoza', 'America/Menominee', 'America/Merida', 'America/Metlakatla', 'America/Mexico_City', 'America/Miquelon', 'America/Moncton', 'America/Monterrey', 'America/Montevideo', 'America/Montreal', 'America/Montserrat', 'America/Nassau', 'America/New_York', 'America/Nipigon', 'America/Nome', 'America/Noronha', 'America/North_Dakota/Beulah', 'America/North_Dakota/Center', 'America/North_Dakota/New_Salem', 'America/Nuuk', 'America/Ojinaga', 'America/Panama', 'America/Pangnirtung', 'America/Paramaribo', 'America/Phoenix', 'America/Port-au-Prince', 'America/Port_of_Spain', 'America/Porto_Acre', 'America/Porto_Velho', 'America/Puerto_Rico', 'America/Punta_Arenas', 'America/Rainy_River', 'America/Rankin_Inlet', 'America/Recif ...

# %% [markdown]
# ### convert current utc time to another timezone

# %%
import pytz
from datetime import datetime
print("###########################")
utcmoment_naive = datetime.utcnow()
print("utc time now :%s"%utcmoment_naive)
print(utcmoment_naive.tzinfo)
print("###########################")
local_time = datetime.now()
print("local time now :%s"%local_time)
print(local_time.tzinfo)
print("###########################")

utcmoment = utcmoment_naive.replace(tzinfo=pytz.utc)
print(utcmoment.tzinfo)
local_time = local_time.replace(tzinfo=pytz.timezone('Indian/Mahe'))
print(local_time.tzinfo)
# print "utcmoment_naive: {0}".format(utcmoment_naive) # python 2
print("utcmoment_naive: {0}".format(utcmoment_naive))
print("utcmoment:       {0}".format(utcmoment))
print("###########################")
localFormat = "%Y-%m-%d %H:%M:%S:%f"
timezones = ['America/Los_Angeles', 'Europe/Madrid', 'America/Puerto_Rico','Asia/Kathmandu']
print("######################")
for tz in timezones:    
    localDatetime = utcmoment.astimezone(pytz.timezone(tz))
    localFormat = "%Y-%m-%d - %H:%M:%S:%f %b %z"
    print(localDatetime.strftime(localFormat))
    #localFormat = "%Y$%m$%d - %H$%M$%S$%f"
# Out:
# ###########################
# utc time now :2022-02-21 04:44:12.669897
# None
# ###########################
# local time now :2022-02-21 10:14:12.669897
# None
# ###########################
# None
# Indian/Mahe
# utcmoment_naive: 2022-02-21 04:44:12.669897
# utcmoment:       2022-02-21 04:44:12.669897
# ###########################
# ######################
# 2022-02-20 - 15:14:12:669897 Feb -0800
# 2022-02-21 - 00:14:12:669897 Feb +0100
# 2022-02-20 - 19:14:12:669897 Feb -0400
# 2022-02-21 - 04:59:12:669897 Feb +0545

# %%
from pytz import all_timezones

utcmoment_naive = datetime.utcnow()
print(utcmoment_naive)

print(utcmoment_naive.tzinfo)
utcmoment = utcmoment_naive.replace(tzinfo=pytz.utc)
print("Current Utc Time :", utcmoment)
print("##############################################")
utcmoment_india = datetime.now()
tzinfo_india = timezone('Asia/Kathmandu')
utcmoment_india = utcmoment_india.replace(tzinfo = tzinfo_india)
print("Current India Time", utcmoment_india)
print("##############################################")
i =0
for timezonename in list(all_timezones):
    if(i>500):
        break
    print("timezone name: {} - current time in that time zone - {}".format(timezonename,utcmoment_india.astimezone(pytz.timezone(timezonename))))
    i+=1
# Out:
# 2022-02-21 04:46:08.781659
# None
# Current Utc Time : 2022-02-21 04:46:08.781659+00:00
# ##############################################
# Current India Time 2022-02-21 10:16:08.781659+05:41
# ##############################################
# timezone name: Africa/Abidjan - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Accra - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Addis_Ababa - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Algiers - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Asmara - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Asmera - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Bamako - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Bangui - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Banjul - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Bissau - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Blantyre - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Brazzaville - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Bujumbura - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Cairo - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Casablanca - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Ceuta - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Conakry - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Dakar - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Dar_es_Salaam - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Djibouti - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Douala - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/El_Aaiun - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Freetown - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Gaborone - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Harare - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Johannesburg - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Juba - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Kampala - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Khartoum - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Kigali - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Kinshasa - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Lagos - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Libreville - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Lome - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Luanda - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Lubumbashi - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Lusaka - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Malabo - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Maputo - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Maseru - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Mbabane - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Mogadishu - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Monrovia - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Nairobi - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Africa/Ndjamena - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Niamey - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Nouakchott - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Ouagadougou - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Porto-Novo - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Sao_Tome - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Timbuktu - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Africa/Tripoli - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Africa/Tunis - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Africa/Windhoek - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: America/Adak - current time in that time zone - 2022-02-20 18:35:08.781659-10:00
# timezone name: America/Anchorage - current time in that time zone - 2022-02-20 19:35:08.781659-09:00
# timezone name: America/Anguilla - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Antigua - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Araguaina - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Buenos_Aires - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Catamarca - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/ComodRivadavia - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Cordoba - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Jujuy - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/La_Rioja - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Mendoza - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Rio_Gallegos - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Salta - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/San_Juan - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/San_Luis - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Tucuman - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Argentina/Ushuaia - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Aruba - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Asuncion - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Atikokan - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Atka - current time in that time zone - 2022-02-20 18:35:08.781659-10:00
# timezone name: America/Bahia - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Bahia_Banderas - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Barbados - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Belem - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Belize - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Blanc-Sablon - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Boa_Vista - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Bogota - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Boise - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Buenos_Aires - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Cambridge_Bay - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Campo_Grande - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Cancun - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Caracas - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Catamarca - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Cayenne - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Cayman - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Chicago - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Chihuahua - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Coral_Harbour - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Cordoba - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Costa_Rica - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Creston - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Cuiaba - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Curacao - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Danmarkshavn - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: America/Dawson - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Dawson_Creek - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Denver - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Detroit - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Dominica - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Edmonton - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Eirunepe - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/El_Salvador - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Ensenada - current time in that time zone - 2022-02-20 20:35:08.781659-08:00
# timezone name: America/Fort_Nelson - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Fort_Wayne - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Fortaleza - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Glace_Bay - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Godthab - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Goose_Bay - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Grand_Turk - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Grenada - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Guadeloupe - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Guatemala - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Guayaquil - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Guyana - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Halifax - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Havana - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Hermosillo - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Indiana/Indianapolis - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Indiana/Knox - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Indiana/Marengo - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Indiana/Petersburg - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Indiana/Tell_City - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Indiana/Vevay - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Indiana/Vincennes - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Indiana/Winamac - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Indianapolis - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Inuvik - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Iqaluit - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Jamaica - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Jujuy - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Juneau - current time in that time zone - 2022-02-20 19:35:08.781659-09:00
# timezone name: America/Kentucky/Louisville - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Kentucky/Monticello - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Knox_IN - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Kralendijk - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/La_Paz - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Lima - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Los_Angeles - current time in that time zone - 2022-02-20 20:35:08.781659-08:00
# timezone name: America/Louisville - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Lower_Princes - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Maceio - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Managua - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Manaus - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Marigot - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Martinique - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Matamoros - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Mazatlan - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Mendoza - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Menominee - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Merida - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Metlakatla - current time in that time zone - 2022-02-20 19:35:08.781659-09:00
# timezone name: America/Mexico_City - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Miquelon - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Moncton - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Monterrey - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Montevideo - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Montreal - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Montserrat - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Nassau - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/New_York - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Nipigon - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Nome - current time in that time zone - 2022-02-20 19:35:08.781659-09:00
# timezone name: America/Noronha - current time in that time zone - 2022-02-21 02:35:08.781659-02:00
# timezone name: America/North_Dakota/Beulah - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/North_Dakota/Center - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/North_Dakota/New_Salem - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Nuuk - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Ojinaga - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Panama - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Pangnirtung - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Paramaribo - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Phoenix - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Port-au-Prince - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Port_of_Spain - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Porto_Acre - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Porto_Velho - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Puerto_Rico - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Punta_Arenas - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Rainy_River - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Rankin_Inlet - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Recife - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Regina - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Resolute - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Rio_Branco - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Rosario - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Santa_Isabel - current time in that time zone - 2022-02-20 20:35:08.781659-08:00
# timezone name: America/Santarem - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Santiago - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Santo_Domingo - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Sao_Paulo - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: America/Scoresbysund - current time in that time zone - 2022-02-21 03:35:08.781659-01:00
# timezone name: America/Shiprock - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Sitka - current time in that time zone - 2022-02-20 19:35:08.781659-09:00
# timezone name: America/St_Barthelemy - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/St_Johns - current time in that time zone - 2022-02-21 01:05:08.781659-03:30
# timezone name: America/St_Kitts - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/St_Lucia - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/St_Thomas - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/St_Vincent - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Swift_Current - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Tegucigalpa - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Thule - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Thunder_Bay - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Tijuana - current time in that time zone - 2022-02-20 20:35:08.781659-08:00
# timezone name: America/Toronto - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: America/Tortola - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Vancouver - current time in that time zone - 2022-02-20 20:35:08.781659-08:00
# timezone name: America/Virgin - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: America/Whitehorse - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: America/Winnipeg - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: America/Yakutat - current time in that time zone - 2022-02-20 19:35:08.781659-09:00
# timezone name: America/Yellowknife - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: Antarctica/Casey - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Antarctica/Davis - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Antarctica/DumontDUrville - current time in that time zone - 2022-02-21 14:35:08.781659+10:00
# timezone name: Antarctica/Macquarie - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Antarctica/Mawson - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Antarctica/McMurdo - current time in that time zone - 2022-02-21 17:35:08.781659+13:00
# timezone name: Antarctica/Palmer - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: Antarctica/Rothera - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: Antarctica/South_Pole - current time in that time zone - 2022-02-21 17:35:08.781659+13:00
# timezone name: Antarctica/Syowa - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Antarctica/Troll - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Antarctica/Vostok - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Arctic/Longyearbyen - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Asia/Aden - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Asia/Almaty - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Amman - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Anadyr - current time in that time zone - 2022-02-21 16:35:08.781659+12:00
# timezone name: Asia/Aqtau - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Aqtobe - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Ashgabat - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Ashkhabad - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Atyrau - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Baghdad - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Asia/Bahrain - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Asia/Baku - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Asia/Bangkok - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Barnaul - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Beirut - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Bishkek - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Brunei - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Calcutta - current time in that time zone - 2022-02-21 10:05:08.781659+05:30
# timezone name: Asia/Chita - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Choibalsan - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Chongqing - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Chungking - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Colombo - current time in that time zone - 2022-02-21 10:05:08.781659+05:30
# timezone name: Asia/Dacca - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Damascus - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Dhaka - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Dili - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Dubai - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Asia/Dushanbe - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Famagusta - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Gaza - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Harbin - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Hebron - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Ho_Chi_Minh - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Hong_Kong - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Hovd - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Irkutsk - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Istanbul - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Asia/Jakarta - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Jayapura - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Jerusalem - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Kabul - current time in that time zone - 2022-02-21 09:05:08.781659+04:30
# timezone name: Asia/Kamchatka - current time in that time zone - 2022-02-21 16:35:08.781659+12:00
# timezone name: Asia/Karachi - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Kashgar - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Kathmandu - current time in that time zone - 2022-02-21 10:16:08.781659+05:41
# timezone name: Asia/Katmandu - current time in that time zone - 2022-02-21 10:20:08.781659+05:45
# timezone name: Asia/Khandyga - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Kolkata - current time in that time zone - 2022-02-21 10:05:08.781659+05:30
# timezone name: Asia/Krasnoyarsk - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Kuala_Lumpur - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Kuching - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Kuwait - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Asia/Macao - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Macau - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Magadan - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Asia/Makassar - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Manila - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Muscat - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Asia/Nicosia - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Novokuznetsk - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Novosibirsk - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Omsk - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Oral - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Phnom_Penh - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Pontianak - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Pyongyang - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Qatar - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Asia/Qostanay - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Qyzylorda - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Rangoon - current time in that time zone - 2022-02-21 11:05:08.781659+06:30
# timezone name: Asia/Riyadh - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Asia/Saigon - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Sakhalin - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Asia/Samarkand - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Seoul - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Shanghai - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Singapore - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Srednekolymsk - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Asia/Taipei - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Tashkent - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Tbilisi - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Asia/Tehran - current time in that time zone - 2022-02-21 08:05:08.781659+03:30
# timezone name: Asia/Tel_Aviv - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Asia/Thimbu - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Thimphu - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Tokyo - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Tomsk - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Ujung_Pandang - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Ulaanbaatar - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Ulan_Bator - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Asia/Urumqi - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Asia/Ust-Nera - current time in that time zone - 2022-02-21 14:35:08.781659+10:00
# timezone name: Asia/Vientiane - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Asia/Vladivostok - current time in that time zone - 2022-02-21 14:35:08.781659+10:00
# timezone name: Asia/Yakutsk - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Asia/Yangon - current time in that time zone - 2022-02-21 11:05:08.781659+06:30
# timezone name: Asia/Yekaterinburg - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Asia/Yerevan - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Atlantic/Azores - current time in that time zone - 2022-02-21 03:35:08.781659-01:00
# timezone name: Atlantic/Bermuda - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: Atlantic/Canary - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Atlantic/Cape_Verde - current time in that time zone - 2022-02-21 03:35:08.781659-01:00
# timezone name: Atlantic/Faeroe - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Atlantic/Faroe - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Atlantic/Jan_Mayen - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Atlantic/Madeira - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Atlantic/Reykjavik - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Atlantic/South_Georgia - current time in that time zone - 2022-02-21 02:35:08.781659-02:00
# timezone name: Atlantic/St_Helena - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Atlantic/Stanley - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: Australia/ACT - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/Adelaide - current time in that time zone - 2022-02-21 15:05:08.781659+10:30
# timezone name: Australia/Brisbane - current time in that time zone - 2022-02-21 14:35:08.781659+10:00
# timezone name: Australia/Broken_Hill - current time in that time zone - 2022-02-21 15:05:08.781659+10:30
# timezone name: Australia/Canberra - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/Currie - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/Darwin - current time in that time zone - 2022-02-21 14:05:08.781659+09:30
# timezone name: Australia/Eucla - current time in that time zone - 2022-02-21 13:20:08.781659+08:45
# timezone name: Australia/Hobart - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/LHI - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/Lindeman - current time in that time zone - 2022-02-21 14:35:08.781659+10:00
# timezone name: Australia/Lord_Howe - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/Melbourne - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/NSW - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/North - current time in that time zone - 2022-02-21 14:05:08.781659+09:30
# timezone name: Australia/Perth - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Australia/Queensland - current time in that time zone - 2022-02-21 14:35:08.781659+10:00
# timezone name: Australia/South - current time in that time zone - 2022-02-21 15:05:08.781659+10:30
# timezone name: Australia/Sydney - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/Tasmania - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/Victoria - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Australia/West - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Australia/Yancowinna - current time in that time zone - 2022-02-21 15:05:08.781659+10:30
# timezone name: Brazil/Acre - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: Brazil/DeNoronha - current time in that time zone - 2022-02-21 02:35:08.781659-02:00
# timezone name: Brazil/East - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: Brazil/West - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: CET - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: CST6CDT - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: Canada/Atlantic - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: Canada/Central - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: Canada/Eastern - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: Canada/Mountain - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: Canada/Newfoundland - current time in that time zone - 2022-02-21 01:05:08.781659-03:30
# timezone name: Canada/Pacific - current time in that time zone - 2022-02-20 20:35:08.781659-08:00
# timezone name: Canada/Saskatchewan - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: Canada/Yukon - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: Chile/Continental - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: Chile/EasterIsland - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: Cuba - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: EET - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: EST - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: EST5EDT - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: Egypt - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Eire - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/GMT - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/GMT+0 - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/GMT+1 - current time in that time zone - 2022-02-21 03:35:08.781659-01:00
# timezone name: Etc/GMT+10 - current time in that time zone - 2022-02-20 18:35:08.781659-10:00
# timezone name: Etc/GMT+11 - current time in that time zone - 2022-02-20 17:35:08.781659-11:00
# timezone name: Etc/GMT+12 - current time in that time zone - 2022-02-20 16:35:08.781659-12:00
# timezone name: Etc/GMT+2 - current time in that time zone - 2022-02-21 02:35:08.781659-02:00
# timezone name: Etc/GMT+3 - current time in that time zone - 2022-02-21 01:35:08.781659-03:00
# timezone name: Etc/GMT+4 - current time in that time zone - 2022-02-21 00:35:08.781659-04:00
# timezone name: Etc/GMT+5 - current time in that time zone - 2022-02-20 23:35:08.781659-05:00
# timezone name: Etc/GMT+6 - current time in that time zone - 2022-02-20 22:35:08.781659-06:00
# timezone name: Etc/GMT+7 - current time in that time zone - 2022-02-20 21:35:08.781659-07:00
# timezone name: Etc/GMT+8 - current time in that time zone - 2022-02-20 20:35:08.781659-08:00
# timezone name: Etc/GMT+9 - current time in that time zone - 2022-02-20 19:35:08.781659-09:00
# timezone name: Etc/GMT-0 - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/GMT-1 - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Etc/GMT-10 - current time in that time zone - 2022-02-21 14:35:08.781659+10:00
# timezone name: Etc/GMT-11 - current time in that time zone - 2022-02-21 15:35:08.781659+11:00
# timezone name: Etc/GMT-12 - current time in that time zone - 2022-02-21 16:35:08.781659+12:00
# timezone name: Etc/GMT-13 - current time in that time zone - 2022-02-21 17:35:08.781659+13:00
# timezone name: Etc/GMT-14 - current time in that time zone - 2022-02-21 18:35:08.781659+14:00
# timezone name: Etc/GMT-2 - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Etc/GMT-3 - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Etc/GMT-4 - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Etc/GMT-5 - current time in that time zone - 2022-02-21 09:35:08.781659+05:00
# timezone name: Etc/GMT-6 - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Etc/GMT-7 - current time in that time zone - 2022-02-21 11:35:08.781659+07:00
# timezone name: Etc/GMT-8 - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Etc/GMT-9 - current time in that time zone - 2022-02-21 13:35:08.781659+09:00
# timezone name: Etc/GMT0 - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/Greenwich - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/UCT - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/UTC - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/Universal - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Etc/Zulu - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Amsterdam - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Andorra - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Astrakhan - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Europe/Athens - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Belfast - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Belgrade - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Berlin - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Bratislava - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Brussels - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Bucharest - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Budapest - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Busingen - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Chisinau - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Copenhagen - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Dublin - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Gibraltar - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Guernsey - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Helsinki - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Isle_of_Man - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Istanbul - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Europe/Jersey - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Kaliningrad - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Kiev - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Kirov - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Europe/Lisbon - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Ljubljana - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/London - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Europe/Luxembourg - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Madrid - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Malta - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Mariehamn - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Minsk - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Europe/Monaco - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Moscow - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Europe/Nicosia - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Oslo - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Paris - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Podgorica - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Prague - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Riga - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Rome - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Samara - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Europe/San_Marino - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Sarajevo - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Saratov - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Europe/Simferopol - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Europe/Skopje - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Sofia - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Stockholm - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Tallinn - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Tirane - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Tiraspol - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Ulyanovsk - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Europe/Uzhgorod - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Vaduz - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Vatican - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Vienna - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Vilnius - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Volgograd - current time in that time zone - 2022-02-21 08:35:08.781659+04:00
# timezone name: Europe/Warsaw - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Zagreb - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: Europe/Zaporozhye - current time in that time zone - 2022-02-21 06:35:08.781659+02:00
# timezone name: Europe/Zurich - current time in that time zone - 2022-02-21 05:35:08.781659+01:00
# timezone name: GB - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: GB-Eire - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: GMT - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: GMT+0 - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: GMT-0 - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: GMT0 - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Greenwich - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: HST - current time in that time zone - 2022-02-20 18:35:08.781659-10:00
# timezone name: Hongkong - current time in that time zone - 2022-02-21 12:35:08.781659+08:00
# timezone name: Iceland - current time in that time zone - 2022-02-21 04:35:08.781659+00:00
# timezone name: Indian/Antananarivo - current time in that time zone - 2022-02-21 07:35:08.781659+03:00
# timezone name: Indian/Chagos - current time in that time zone - 2022-02-21 10:35:08.781659+06:00
# timezone name: Indian/Christmas - current time in that time zone - 2022-02-21 11:35:08.781659+07:00

# %%
#### 'TimeZones Starting with 'B'

# %%
from pytz import all_timezones
utcmoment_naive = datetime.now()
print(utcmoment_naive)
print(utcmoment_naive.tzinfo)
utcmoment = datetime.utcnow()
print(utcmoment)
print(utcmoment.tzinfo)
utcmoment = utcmoment.replace(tzinfo=pytz.utc)
print(utcmoment.tzinfo)
print("Current Utc Time :", utcmoment)
for timezonename in list(all_timezones):
    if(timezonename.startswith('A')):
        print("timezone name: {} - current time in that time zone - {}".format(timezonename,utcmoment.astimezone(pytz.timezone(timezonename))))
        print(type(pytz.timezone(timezonename)),pytz.timezone(timezonename))
# Out:
# 2022-02-21 10:18:38.590323
# None
# 2022-02-21 04:48:38.591343
# None
# UTC
# Current Utc Time : 2022-02-21 04:48:38.591343+00:00
# timezone name: Africa/Abidjan - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Abidjan'> Africa/Abidjan
# timezone name: Africa/Accra - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Accra'> Africa/Accra
# timezone name: Africa/Addis_Ababa - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Addis_Ababa'> Africa/Addis_Ababa
# timezone name: Africa/Algiers - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Algiers'> Africa/Algiers
# timezone name: Africa/Asmara - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Asmara'> Africa/Asmara
# timezone name: Africa/Asmera - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Asmera'> Africa/Asmera
# timezone name: Africa/Bamako - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Bamako'> Africa/Bamako
# timezone name: Africa/Bangui - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Bangui'> Africa/Bangui
# timezone name: Africa/Banjul - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Banjul'> Africa/Banjul
# timezone name: Africa/Bissau - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Bissau'> Africa/Bissau
# timezone name: Africa/Blantyre - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Blantyre'> Africa/Blantyre
# timezone name: Africa/Brazzaville - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Brazzaville'> Africa/Brazzaville
# timezone name: Africa/Bujumbura - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Bujumbura'> Africa/Bujumbura
# timezone name: Africa/Cairo - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Cairo'> Africa/Cairo
# timezone name: Africa/Casablanca - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Casablanca'> Africa/Casablanca
# timezone name: Africa/Ceuta - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Ceuta'> Africa/Ceuta
# timezone name: Africa/Conakry - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Conakry'> Africa/Conakry
# timezone name: Africa/Dakar - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Dakar'> Africa/Dakar
# timezone name: Africa/Dar_es_Salaam - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Dar_es_Salaam'> Africa/Dar_es_Salaam
# timezone name: Africa/Djibouti - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Djibouti'> Africa/Djibouti
# timezone name: Africa/Douala - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Douala'> Africa/Douala
# timezone name: Africa/El_Aaiun - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/El_Aaiun'> Africa/El_Aaiun
# timezone name: Africa/Freetown - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Freetown'> Africa/Freetown
# timezone name: Africa/Gaborone - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Gaborone'> Africa/Gaborone
# timezone name: Africa/Harare - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Harare'> Africa/Harare
# timezone name: Africa/Johannesburg - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Johannesburg'> Africa/Johannesburg
# timezone name: Africa/Juba - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Juba'> Africa/Juba
# timezone name: Africa/Kampala - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Kampala'> Africa/Kampala
# timezone name: Africa/Khartoum - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Khartoum'> Africa/Khartoum
# timezone name: Africa/Kigali - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Kigali'> Africa/Kigali
# timezone name: Africa/Kinshasa - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Kinshasa'> Africa/Kinshasa
# timezone name: Africa/Lagos - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Lagos'> Africa/Lagos
# timezone name: Africa/Libreville - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Libreville'> Africa/Libreville
# timezone name: Africa/Lome - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Lome'> Africa/Lome
# timezone name: Africa/Luanda - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Luanda'> Africa/Luanda
# timezone name: Africa/Lubumbashi - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Lubumbashi'> Africa/Lubumbashi
# timezone name: Africa/Lusaka - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Lusaka'> Africa/Lusaka
# timezone name: Africa/Malabo - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Malabo'> Africa/Malabo
# timezone name: Africa/Maputo - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Maputo'> Africa/Maputo
# timezone name: Africa/Maseru - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Maseru'> Africa/Maseru
# timezone name: Africa/Mbabane - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Mbabane'> Africa/Mbabane
# timezone name: Africa/Mogadishu - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Mogadishu'> Africa/Mogadishu
# timezone name: Africa/Monrovia - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Monrovia'> Africa/Monrovia
# timezone name: Africa/Nairobi - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Africa/Nairobi'> Africa/Nairobi
# timezone name: Africa/Ndjamena - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Ndjamena'> Africa/Ndjamena
# timezone name: Africa/Niamey - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Niamey'> Africa/Niamey
# timezone name: Africa/Nouakchott - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Nouakchott'> Africa/Nouakchott
# timezone name: Africa/Ouagadougou - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Ouagadougou'> Africa/Ouagadougou
# timezone name: Africa/Porto-Novo - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Porto-Novo'> Africa/Porto-Novo
# timezone name: Africa/Sao_Tome - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Sao_Tome'> Africa/Sao_Tome
# timezone name: Africa/Timbuktu - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Africa/Timbuktu'> Africa/Timbuktu
# timezone name: Africa/Tripoli - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Tripoli'> Africa/Tripoli
# timezone name: Africa/Tunis - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Africa/Tunis'> Africa/Tunis
# timezone name: Africa/Windhoek - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Africa/Windhoek'> Africa/Windhoek
# timezone name: America/Adak - current time in that time zone - 2022-02-20 18:48:38.591343-10:00
# <class 'pytz.tzfile.America/Adak'> America/Adak
# timezone name: America/Anchorage - current time in that time zone - 2022-02-20 19:48:38.591343-09:00
# <class 'pytz.tzfile.America/Anchorage'> America/Anchorage
# timezone name: America/Anguilla - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Anguilla'> America/Anguilla
# timezone name: America/Antigua - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Antigua'> America/Antigua
# timezone name: America/Araguaina - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Araguaina'> America/Araguaina
# timezone name: America/Argentina/Buenos_Aires - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Buenos_Aires'> America/Argentina/Buenos_Aires
# timezone name: America/Argentina/Catamarca - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Catamarca'> America/Argentina/Catamarca
# timezone name: America/Argentina/ComodRivadavia - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/ComodRivadavia'> America/Argentina/ComodRivadavia
# timezone name: America/Argentina/Cordoba - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Cordoba'> America/Argentina/Cordoba
# timezone name: America/Argentina/Jujuy - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Jujuy'> America/Argentina/Jujuy
# timezone name: America/Argentina/La_Rioja - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/La_Rioja'> America/Argentina/La_Rioja
# timezone name: America/Argentina/Mendoza - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Mendoza'> America/Argentina/Mendoza
# timezone name: America/Argentina/Rio_Gallegos - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Rio_Gallegos'> America/Argentina/Rio_Gallegos
# timezone name: America/Argentina/Salta - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Salta'> America/Argentina/Salta
# timezone name: America/Argentina/San_Juan - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/San_Juan'> America/Argentina/San_Juan
# timezone name: America/Argentina/San_Luis - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/San_Luis'> America/Argentina/San_Luis
# timezone name: America/Argentina/Tucuman - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Tucuman'> America/Argentina/Tucuman
# timezone name: America/Argentina/Ushuaia - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Argentina/Ushuaia'> America/Argentina/Ushuaia
# timezone name: America/Aruba - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Aruba'> America/Aruba
# timezone name: America/Asuncion - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Asuncion'> America/Asuncion
# timezone name: America/Atikokan - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Atikokan'> America/Atikokan
# timezone name: America/Atka - current time in that time zone - 2022-02-20 18:48:38.591343-10:00
# <class 'pytz.tzfile.America/Atka'> America/Atka
# timezone name: America/Bahia - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Bahia'> America/Bahia
# timezone name: America/Bahia_Banderas - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Bahia_Banderas'> America/Bahia_Banderas
# timezone name: America/Barbados - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Barbados'> America/Barbados
# timezone name: America/Belem - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Belem'> America/Belem
# timezone name: America/Belize - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Belize'> America/Belize
# timezone name: America/Blanc-Sablon - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Blanc-Sablon'> America/Blanc-Sablon
# timezone name: America/Boa_Vista - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Boa_Vista'> America/Boa_Vista
# timezone name: America/Bogota - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Bogota'> America/Bogota
# timezone name: America/Boise - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Boise'> America/Boise
# timezone name: America/Buenos_Aires - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Buenos_Aires'> America/Buenos_Aires
# timezone name: America/Cambridge_Bay - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Cambridge_Bay'> America/Cambridge_Bay
# timezone name: America/Campo_Grande - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Campo_Grande'> America/Campo_Grande
# timezone name: America/Cancun - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Cancun'> America/Cancun
# timezone name: America/Caracas - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Caracas'> America/Caracas
# timezone name: America/Catamarca - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Catamarca'> America/Catamarca
# timezone name: America/Cayenne - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Cayenne'> America/Cayenne
# timezone name: America/Cayman - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Cayman'> America/Cayman
# timezone name: America/Chicago - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Chicago'> America/Chicago
# timezone name: America/Chihuahua - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Chihuahua'> America/Chihuahua
# timezone name: America/Coral_Harbour - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Coral_Harbour'> America/Coral_Harbour
# timezone name: America/Cordoba - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Cordoba'> America/Cordoba
# timezone name: America/Costa_Rica - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Costa_Rica'> America/Costa_Rica
# timezone name: America/Creston - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Creston'> America/Creston
# timezone name: America/Cuiaba - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Cuiaba'> America/Cuiaba
# timezone name: America/Curacao - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Curacao'> America/Curacao
# timezone name: America/Danmarkshavn - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.America/Danmarkshavn'> America/Danmarkshavn
# timezone name: America/Dawson - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Dawson'> America/Dawson
# timezone name: America/Dawson_Creek - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Dawson_Creek'> America/Dawson_Creek
# timezone name: America/Denver - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Denver'> America/Denver
# timezone name: America/Detroit - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Detroit'> America/Detroit
# timezone name: America/Dominica - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Dominica'> America/Dominica
# timezone name: America/Edmonton - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Edmonton'> America/Edmonton
# timezone name: America/Eirunepe - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Eirunepe'> America/Eirunepe
# timezone name: America/El_Salvador - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/El_Salvador'> America/El_Salvador
# timezone name: America/Ensenada - current time in that time zone - 2022-02-20 20:48:38.591343-08:00
# <class 'pytz.tzfile.America/Ensenada'> America/Ensenada
# timezone name: America/Fort_Nelson - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Fort_Nelson'> America/Fort_Nelson
# timezone name: America/Fort_Wayne - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Fort_Wayne'> America/Fort_Wayne
# timezone name: America/Fortaleza - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Fortaleza'> America/Fortaleza
# timezone name: America/Glace_Bay - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Glace_Bay'> America/Glace_Bay
# timezone name: America/Godthab - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Godthab'> America/Godthab
# timezone name: America/Goose_Bay - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Goose_Bay'> America/Goose_Bay
# timezone name: America/Grand_Turk - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Grand_Turk'> America/Grand_Turk
# timezone name: America/Grenada - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Grenada'> America/Grenada
# timezone name: America/Guadeloupe - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Guadeloupe'> America/Guadeloupe
# timezone name: America/Guatemala - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Guatemala'> America/Guatemala
# timezone name: America/Guayaquil - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Guayaquil'> America/Guayaquil
# timezone name: America/Guyana - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Guyana'> America/Guyana
# timezone name: America/Halifax - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Halifax'> America/Halifax
# timezone name: America/Havana - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Havana'> America/Havana
# timezone name: America/Hermosillo - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Hermosillo'> America/Hermosillo
# timezone name: America/Indiana/Indianapolis - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Indiana/Indianapolis'> America/Indiana/Indianapolis
# timezone name: America/Indiana/Knox - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Indiana/Knox'> America/Indiana/Knox
# timezone name: America/Indiana/Marengo - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Indiana/Marengo'> America/Indiana/Marengo
# timezone name: America/Indiana/Petersburg - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Indiana/Petersburg'> America/Indiana/Petersburg
# timezone name: America/Indiana/Tell_City - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Indiana/Tell_City'> America/Indiana/Tell_City
# timezone name: America/Indiana/Vevay - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Indiana/Vevay'> America/Indiana/Vevay
# timezone name: America/Indiana/Vincennes - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Indiana/Vincennes'> America/Indiana/Vincennes
# timezone name: America/Indiana/Winamac - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Indiana/Winamac'> America/Indiana/Winamac
# timezone name: America/Indianapolis - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Indianapolis'> America/Indianapolis
# timezone name: America/Inuvik - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Inuvik'> America/Inuvik
# timezone name: America/Iqaluit - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Iqaluit'> America/Iqaluit
# timezone name: America/Jamaica - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Jamaica'> America/Jamaica
# timezone name: America/Jujuy - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Jujuy'> America/Jujuy
# timezone name: America/Juneau - current time in that time zone - 2022-02-20 19:48:38.591343-09:00
# <class 'pytz.tzfile.America/Juneau'> America/Juneau
# timezone name: America/Kentucky/Louisville - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Kentucky/Louisville'> America/Kentucky/Louisville
# timezone name: America/Kentucky/Monticello - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Kentucky/Monticello'> America/Kentucky/Monticello
# timezone name: America/Knox_IN - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Knox_IN'> America/Knox_IN
# timezone name: America/Kralendijk - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Kralendijk'> America/Kralendijk
# timezone name: America/La_Paz - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/La_Paz'> America/La_Paz
# timezone name: America/Lima - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Lima'> America/Lima
# timezone name: America/Los_Angeles - current time in that time zone - 2022-02-20 20:48:38.591343-08:00
# <class 'pytz.tzfile.America/Los_Angeles'> America/Los_Angeles
# timezone name: America/Louisville - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Louisville'> America/Louisville
# timezone name: America/Lower_Princes - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Lower_Princes'> America/Lower_Princes
# timezone name: America/Maceio - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Maceio'> America/Maceio
# timezone name: America/Managua - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Managua'> America/Managua
# timezone name: America/Manaus - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Manaus'> America/Manaus
# timezone name: America/Marigot - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Marigot'> America/Marigot
# timezone name: America/Martinique - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Martinique'> America/Martinique
# timezone name: America/Matamoros - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Matamoros'> America/Matamoros
# timezone name: America/Mazatlan - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Mazatlan'> America/Mazatlan
# timezone name: America/Mendoza - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Mendoza'> America/Mendoza
# timezone name: America/Menominee - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Menominee'> America/Menominee
# timezone name: America/Merida - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Merida'> America/Merida
# timezone name: America/Metlakatla - current time in that time zone - 2022-02-20 19:48:38.591343-09:00
# <class 'pytz.tzfile.America/Metlakatla'> America/Metlakatla
# timezone name: America/Mexico_City - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Mexico_City'> America/Mexico_City
# timezone name: America/Miquelon - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Miquelon'> America/Miquelon
# timezone name: America/Moncton - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Moncton'> America/Moncton
# timezone name: America/Monterrey - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Monterrey'> America/Monterrey
# timezone name: America/Montevideo - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Montevideo'> America/Montevideo
# timezone name: America/Montreal - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Montreal'> America/Montreal
# timezone name: America/Montserrat - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Montserrat'> America/Montserrat
# timezone name: America/Nassau - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Nassau'> America/Nassau
# timezone name: America/New_York - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/New_York'> America/New_York
# timezone name: America/Nipigon - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Nipigon'> America/Nipigon
# timezone name: America/Nome - current time in that time zone - 2022-02-20 19:48:38.591343-09:00
# <class 'pytz.tzfile.America/Nome'> America/Nome
# timezone name: America/Noronha - current time in that time zone - 2022-02-21 02:48:38.591343-02:00
# <class 'pytz.tzfile.America/Noronha'> America/Noronha
# timezone name: America/North_Dakota/Beulah - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/North_Dakota/Beulah'> America/North_Dakota/Beulah
# timezone name: America/North_Dakota/Center - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/North_Dakota/Center'> America/North_Dakota/Center
# timezone name: America/North_Dakota/New_Salem - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/North_Dakota/New_Salem'> America/North_Dakota/New_Salem
# timezone name: America/Nuuk - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Nuuk'> America/Nuuk
# timezone name: America/Ojinaga - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Ojinaga'> America/Ojinaga
# timezone name: America/Panama - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Panama'> America/Panama
# timezone name: America/Pangnirtung - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Pangnirtung'> America/Pangnirtung
# timezone name: America/Paramaribo - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Paramaribo'> America/Paramaribo
# timezone name: America/Phoenix - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Phoenix'> America/Phoenix
# timezone name: America/Port-au-Prince - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Port-au-Prince'> America/Port-au-Prince
# timezone name: America/Port_of_Spain - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Port_of_Spain'> America/Port_of_Spain
# timezone name: America/Porto_Acre - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Porto_Acre'> America/Porto_Acre
# timezone name: America/Porto_Velho - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Porto_Velho'> America/Porto_Velho
# timezone name: America/Puerto_Rico - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Puerto_Rico'> America/Puerto_Rico
# timezone name: America/Punta_Arenas - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Punta_Arenas'> America/Punta_Arenas
# timezone name: America/Rainy_River - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Rainy_River'> America/Rainy_River
# timezone name: America/Rankin_Inlet - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Rankin_Inlet'> America/Rankin_Inlet
# timezone name: America/Recife - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Recife'> America/Recife
# timezone name: America/Regina - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Regina'> America/Regina
# timezone name: America/Resolute - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Resolute'> America/Resolute
# timezone name: America/Rio_Branco - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Rio_Branco'> America/Rio_Branco
# timezone name: America/Rosario - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Rosario'> America/Rosario
# timezone name: America/Santa_Isabel - current time in that time zone - 2022-02-20 20:48:38.591343-08:00
# <class 'pytz.tzfile.America/Santa_Isabel'> America/Santa_Isabel
# timezone name: America/Santarem - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Santarem'> America/Santarem
# timezone name: America/Santiago - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Santiago'> America/Santiago
# timezone name: America/Santo_Domingo - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Santo_Domingo'> America/Santo_Domingo
# timezone name: America/Sao_Paulo - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.America/Sao_Paulo'> America/Sao_Paulo
# timezone name: America/Scoresbysund - current time in that time zone - 2022-02-21 03:48:38.591343-01:00
# <class 'pytz.tzfile.America/Scoresbysund'> America/Scoresbysund
# timezone name: America/Shiprock - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Shiprock'> America/Shiprock
# timezone name: America/Sitka - current time in that time zone - 2022-02-20 19:48:38.591343-09:00
# <class 'pytz.tzfile.America/Sitka'> America/Sitka
# timezone name: America/St_Barthelemy - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/St_Barthelemy'> America/St_Barthelemy
# timezone name: America/St_Johns - current time in that time zone - 2022-02-21 01:18:38.591343-03:30
# <class 'pytz.tzfile.America/St_Johns'> America/St_Johns
# timezone name: America/St_Kitts - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/St_Kitts'> America/St_Kitts
# timezone name: America/St_Lucia - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/St_Lucia'> America/St_Lucia
# timezone name: America/St_Thomas - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/St_Thomas'> America/St_Thomas
# timezone name: America/St_Vincent - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/St_Vincent'> America/St_Vincent
# timezone name: America/Swift_Current - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Swift_Current'> America/Swift_Current
# timezone name: America/Tegucigalpa - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Tegucigalpa'> America/Tegucigalpa
# timezone name: America/Thule - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Thule'> America/Thule
# timezone name: America/Thunder_Bay - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Thunder_Bay'> America/Thunder_Bay
# timezone name: America/Tijuana - current time in that time zone - 2022-02-20 20:48:38.591343-08:00
# <class 'pytz.tzfile.America/Tijuana'> America/Tijuana
# timezone name: America/Toronto - current time in that time zone - 2022-02-20 23:48:38.591343-05:00
# <class 'pytz.tzfile.America/Toronto'> America/Toronto
# timezone name: America/Tortola - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Tortola'> America/Tortola
# timezone name: America/Vancouver - current time in that time zone - 2022-02-20 20:48:38.591343-08:00
# <class 'pytz.tzfile.America/Vancouver'> America/Vancouver
# timezone name: America/Virgin - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.America/Virgin'> America/Virgin
# timezone name: America/Whitehorse - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Whitehorse'> America/Whitehorse
# timezone name: America/Winnipeg - current time in that time zone - 2022-02-20 22:48:38.591343-06:00
# <class 'pytz.tzfile.America/Winnipeg'> America/Winnipeg
# timezone name: America/Yakutat - current time in that time zone - 2022-02-20 19:48:38.591343-09:00
# <class 'pytz.tzfile.America/Yakutat'> America/Yakutat
# timezone name: America/Yellowknife - current time in that time zone - 2022-02-20 21:48:38.591343-07:00
# <class 'pytz.tzfile.America/Yellowknife'> America/Yellowknife
# timezone name: Antarctica/Casey - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Antarctica/Casey'> Antarctica/Casey
# timezone name: Antarctica/Davis - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Antarctica/Davis'> Antarctica/Davis
# timezone name: Antarctica/DumontDUrville - current time in that time zone - 2022-02-21 14:48:38.591343+10:00
# <class 'pytz.tzfile.Antarctica/DumontDUrville'> Antarctica/DumontDUrville
# timezone name: Antarctica/Macquarie - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Antarctica/Macquarie'> Antarctica/Macquarie
# timezone name: Antarctica/Mawson - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Antarctica/Mawson'> Antarctica/Mawson
# timezone name: Antarctica/McMurdo - current time in that time zone - 2022-02-21 17:48:38.591343+13:00
# <class 'pytz.tzfile.Antarctica/McMurdo'> Antarctica/McMurdo
# timezone name: Antarctica/Palmer - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.Antarctica/Palmer'> Antarctica/Palmer
# timezone name: Antarctica/Rothera - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.Antarctica/Rothera'> Antarctica/Rothera
# timezone name: Antarctica/South_Pole - current time in that time zone - 2022-02-21 17:48:38.591343+13:00
# <class 'pytz.tzfile.Antarctica/South_Pole'> Antarctica/South_Pole
# timezone name: Antarctica/Syowa - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Antarctica/Syowa'> Antarctica/Syowa
# timezone name: Antarctica/Troll - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Antarctica/Troll'> Antarctica/Troll
# timezone name: Antarctica/Vostok - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Antarctica/Vostok'> Antarctica/Vostok
# timezone name: Arctic/Longyearbyen - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Arctic/Longyearbyen'> Arctic/Longyearbyen
# timezone name: Asia/Aden - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Asia/Aden'> Asia/Aden
# timezone name: Asia/Almaty - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Almaty'> Asia/Almaty
# timezone name: Asia/Amman - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Amman'> Asia/Amman
# timezone name: Asia/Anadyr - current time in that time zone - 2022-02-21 16:48:38.591343+12:00
# <class 'pytz.tzfile.Asia/Anadyr'> Asia/Anadyr
# timezone name: Asia/Aqtau - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Aqtau'> Asia/Aqtau
# timezone name: Asia/Aqtobe - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Aqtobe'> Asia/Aqtobe
# timezone name: Asia/Ashgabat - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Ashgabat'> Asia/Ashgabat
# timezone name: Asia/Ashkhabad - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Ashkhabad'> Asia/Ashkhabad
# timezone name: Asia/Atyrau - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Atyrau'> Asia/Atyrau
# timezone name: Asia/Baghdad - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Asia/Baghdad'> Asia/Baghdad
# timezone name: Asia/Bahrain - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Asia/Bahrain'> Asia/Bahrain
# timezone name: Asia/Baku - current time in that time zone - 2022-02-21 08:48:38.591343+04:00
# <class 'pytz.tzfile.Asia/Baku'> Asia/Baku
# timezone name: Asia/Bangkok - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Bangkok'> Asia/Bangkok
# timezone name: Asia/Barnaul - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Barnaul'> Asia/Barnaul
# timezone name: Asia/Beirut - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Beirut'> Asia/Beirut
# timezone name: Asia/Bishkek - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Bishkek'> Asia/Bishkek
# timezone name: Asia/Brunei - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Brunei'> Asia/Brunei
# timezone name: Asia/Calcutta - current time in that time zone - 2022-02-21 10:18:38.591343+05:30
# <class 'pytz.tzfile.Asia/Calcutta'> Asia/Calcutta
# timezone name: Asia/Chita - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Chita'> Asia/Chita
# timezone name: Asia/Choibalsan - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Choibalsan'> Asia/Choibalsan
# timezone name: Asia/Chongqing - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Chongqing'> Asia/Chongqing
# timezone name: Asia/Chungking - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Chungking'> Asia/Chungking
# timezone name: Asia/Colombo - current time in that time zone - 2022-02-21 10:18:38.591343+05:30
# <class 'pytz.tzfile.Asia/Colombo'> Asia/Colombo
# timezone name: Asia/Dacca - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Dacca'> Asia/Dacca
# timezone name: Asia/Damascus - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Damascus'> Asia/Damascus
# timezone name: Asia/Dhaka - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Dhaka'> Asia/Dhaka
# timezone name: Asia/Dili - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Dili'> Asia/Dili
# timezone name: Asia/Dubai - current time in that time zone - 2022-02-21 08:48:38.591343+04:00
# <class 'pytz.tzfile.Asia/Dubai'> Asia/Dubai
# timezone name: Asia/Dushanbe - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Dushanbe'> Asia/Dushanbe
# timezone name: Asia/Famagusta - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Famagusta'> Asia/Famagusta
# timezone name: Asia/Gaza - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Gaza'> Asia/Gaza
# timezone name: Asia/Harbin - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Harbin'> Asia/Harbin
# timezone name: Asia/Hebron - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Hebron'> Asia/Hebron
# timezone name: Asia/Ho_Chi_Minh - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Ho_Chi_Minh'> Asia/Ho_Chi_Minh
# timezone name: Asia/Hong_Kong - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Hong_Kong'> Asia/Hong_Kong
# timezone name: Asia/Hovd - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Hovd'> Asia/Hovd
# timezone name: Asia/Irkutsk - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Irkutsk'> Asia/Irkutsk
# timezone name: Asia/Istanbul - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Asia/Istanbul'> Asia/Istanbul
# timezone name: Asia/Jakarta - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Jakarta'> Asia/Jakarta
# timezone name: Asia/Jayapura - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Jayapura'> Asia/Jayapura
# timezone name: Asia/Jerusalem - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Jerusalem'> Asia/Jerusalem
# timezone name: Asia/Kabul - current time in that time zone - 2022-02-21 09:18:38.591343+04:30
# <class 'pytz.tzfile.Asia/Kabul'> Asia/Kabul
# timezone name: Asia/Kamchatka - current time in that time zone - 2022-02-21 16:48:38.591343+12:00
# <class 'pytz.tzfile.Asia/Kamchatka'> Asia/Kamchatka
# timezone name: Asia/Karachi - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Karachi'> Asia/Karachi
# timezone name: Asia/Kashgar - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Kashgar'> Asia/Kashgar
# timezone name: Asia/Kathmandu - current time in that time zone - 2022-02-21 10:33:38.591343+05:45
# <class 'pytz.tzfile.Asia/Kathmandu'> Asia/Kathmandu
# timezone name: Asia/Katmandu - current time in that time zone - 2022-02-21 10:33:38.591343+05:45
# <class 'pytz.tzfile.Asia/Katmandu'> Asia/Katmandu
# timezone name: Asia/Khandyga - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Khandyga'> Asia/Khandyga
# timezone name: Asia/Kolkata - current time in that time zone - 2022-02-21 10:18:38.591343+05:30
# <class 'pytz.tzfile.Asia/Kolkata'> Asia/Kolkata
# timezone name: Asia/Krasnoyarsk - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Krasnoyarsk'> Asia/Krasnoyarsk
# timezone name: Asia/Kuala_Lumpur - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Kuala_Lumpur'> Asia/Kuala_Lumpur
# timezone name: Asia/Kuching - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Kuching'> Asia/Kuching
# timezone name: Asia/Kuwait - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Asia/Kuwait'> Asia/Kuwait
# timezone name: Asia/Macao - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Macao'> Asia/Macao
# timezone name: Asia/Macau - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Macau'> Asia/Macau
# timezone name: Asia/Magadan - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Asia/Magadan'> Asia/Magadan
# timezone name: Asia/Makassar - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Makassar'> Asia/Makassar
# timezone name: Asia/Manila - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Manila'> Asia/Manila
# timezone name: Asia/Muscat - current time in that time zone - 2022-02-21 08:48:38.591343+04:00
# <class 'pytz.tzfile.Asia/Muscat'> Asia/Muscat
# timezone name: Asia/Nicosia - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Nicosia'> Asia/Nicosia
# timezone name: Asia/Novokuznetsk - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Novokuznetsk'> Asia/Novokuznetsk
# timezone name: Asia/Novosibirsk - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Novosibirsk'> Asia/Novosibirsk
# timezone name: Asia/Omsk - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Omsk'> Asia/Omsk
# timezone name: Asia/Oral - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Oral'> Asia/Oral
# timezone name: Asia/Phnom_Penh - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Phnom_Penh'> Asia/Phnom_Penh
# timezone name: Asia/Pontianak - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Pontianak'> Asia/Pontianak
# timezone name: Asia/Pyongyang - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Pyongyang'> Asia/Pyongyang
# timezone name: Asia/Qatar - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Asia/Qatar'> Asia/Qatar
# timezone name: Asia/Qostanay - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Qostanay'> Asia/Qostanay
# timezone name: Asia/Qyzylorda - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Qyzylorda'> Asia/Qyzylorda
# timezone name: Asia/Rangoon - current time in that time zone - 2022-02-21 11:18:38.591343+06:30
# <class 'pytz.tzfile.Asia/Rangoon'> Asia/Rangoon
# timezone name: Asia/Riyadh - current time in that time zone - 2022-02-21 07:48:38.591343+03:00
# <class 'pytz.tzfile.Asia/Riyadh'> Asia/Riyadh
# timezone name: Asia/Saigon - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Saigon'> Asia/Saigon
# timezone name: Asia/Sakhalin - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Asia/Sakhalin'> Asia/Sakhalin
# timezone name: Asia/Samarkand - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Samarkand'> Asia/Samarkand
# timezone name: Asia/Seoul - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Seoul'> Asia/Seoul
# timezone name: Asia/Shanghai - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Shanghai'> Asia/Shanghai
# timezone name: Asia/Singapore - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Singapore'> Asia/Singapore
# timezone name: Asia/Srednekolymsk - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Asia/Srednekolymsk'> Asia/Srednekolymsk
# timezone name: Asia/Taipei - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Taipei'> Asia/Taipei
# timezone name: Asia/Tashkent - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Tashkent'> Asia/Tashkent
# timezone name: Asia/Tbilisi - current time in that time zone - 2022-02-21 08:48:38.591343+04:00
# <class 'pytz.tzfile.Asia/Tbilisi'> Asia/Tbilisi
# timezone name: Asia/Tehran - current time in that time zone - 2022-02-21 08:18:38.591343+03:30
# <class 'pytz.tzfile.Asia/Tehran'> Asia/Tehran
# timezone name: Asia/Tel_Aviv - current time in that time zone - 2022-02-21 06:48:38.591343+02:00
# <class 'pytz.tzfile.Asia/Tel_Aviv'> Asia/Tel_Aviv
# timezone name: Asia/Thimbu - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Thimbu'> Asia/Thimbu
# timezone name: Asia/Thimphu - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Thimphu'> Asia/Thimphu
# timezone name: Asia/Tokyo - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Tokyo'> Asia/Tokyo
# timezone name: Asia/Tomsk - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Tomsk'> Asia/Tomsk
# timezone name: Asia/Ujung_Pandang - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Ujung_Pandang'> Asia/Ujung_Pandang
# timezone name: Asia/Ulaanbaatar - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Ulaanbaatar'> Asia/Ulaanbaatar
# timezone name: Asia/Ulan_Bator - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Asia/Ulan_Bator'> Asia/Ulan_Bator
# timezone name: Asia/Urumqi - current time in that time zone - 2022-02-21 10:48:38.591343+06:00
# <class 'pytz.tzfile.Asia/Urumqi'> Asia/Urumqi
# timezone name: Asia/Ust-Nera - current time in that time zone - 2022-02-21 14:48:38.591343+10:00
# <class 'pytz.tzfile.Asia/Ust-Nera'> Asia/Ust-Nera
# timezone name: Asia/Vientiane - current time in that time zone - 2022-02-21 11:48:38.591343+07:00
# <class 'pytz.tzfile.Asia/Vientiane'> Asia/Vientiane
# timezone name: Asia/Vladivostok - current time in that time zone - 2022-02-21 14:48:38.591343+10:00
# <class 'pytz.tzfile.Asia/Vladivostok'> Asia/Vladivostok
# timezone name: Asia/Yakutsk - current time in that time zone - 2022-02-21 13:48:38.591343+09:00
# <class 'pytz.tzfile.Asia/Yakutsk'> Asia/Yakutsk
# timezone name: Asia/Yangon - current time in that time zone - 2022-02-21 11:18:38.591343+06:30
# <class 'pytz.tzfile.Asia/Yangon'> Asia/Yangon
# timezone name: Asia/Yekaterinburg - current time in that time zone - 2022-02-21 09:48:38.591343+05:00
# <class 'pytz.tzfile.Asia/Yekaterinburg'> Asia/Yekaterinburg
# timezone name: Asia/Yerevan - current time in that time zone - 2022-02-21 08:48:38.591343+04:00
# <class 'pytz.tzfile.Asia/Yerevan'> Asia/Yerevan
# timezone name: Atlantic/Azores - current time in that time zone - 2022-02-21 03:48:38.591343-01:00
# <class 'pytz.tzfile.Atlantic/Azores'> Atlantic/Azores
# timezone name: Atlantic/Bermuda - current time in that time zone - 2022-02-21 00:48:38.591343-04:00
# <class 'pytz.tzfile.Atlantic/Bermuda'> Atlantic/Bermuda
# timezone name: Atlantic/Canary - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Atlantic/Canary'> Atlantic/Canary
# timezone name: Atlantic/Cape_Verde - current time in that time zone - 2022-02-21 03:48:38.591343-01:00
# <class 'pytz.tzfile.Atlantic/Cape_Verde'> Atlantic/Cape_Verde
# timezone name: Atlantic/Faeroe - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Atlantic/Faeroe'> Atlantic/Faeroe
# timezone name: Atlantic/Faroe - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Atlantic/Faroe'> Atlantic/Faroe
# timezone name: Atlantic/Jan_Mayen - current time in that time zone - 2022-02-21 05:48:38.591343+01:00
# <class 'pytz.tzfile.Atlantic/Jan_Mayen'> Atlantic/Jan_Mayen
# timezone name: Atlantic/Madeira - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Atlantic/Madeira'> Atlantic/Madeira
# timezone name: Atlantic/Reykjavik - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Atlantic/Reykjavik'> Atlantic/Reykjavik
# timezone name: Atlantic/South_Georgia - current time in that time zone - 2022-02-21 02:48:38.591343-02:00
# <class 'pytz.tzfile.Atlantic/South_Georgia'> Atlantic/South_Georgia
# timezone name: Atlantic/St_Helena - current time in that time zone - 2022-02-21 04:48:38.591343+00:00
# <class 'pytz.tzfile.Atlantic/St_Helena'> Atlantic/St_Helena
# timezone name: Atlantic/Stanley - current time in that time zone - 2022-02-21 01:48:38.591343-03:00
# <class 'pytz.tzfile.Atlantic/Stanley'> Atlantic/Stanley
# timezone name: Australia/ACT - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/ACT'> Australia/ACT
# timezone name: Australia/Adelaide - current time in that time zone - 2022-02-21 15:18:38.591343+10:30
# <class 'pytz.tzfile.Australia/Adelaide'> Australia/Adelaide
# timezone name: Australia/Brisbane - current time in that time zone - 2022-02-21 14:48:38.591343+10:00
# <class 'pytz.tzfile.Australia/Brisbane'> Australia/Brisbane
# timezone name: Australia/Broken_Hill - current time in that time zone - 2022-02-21 15:18:38.591343+10:30
# <class 'pytz.tzfile.Australia/Broken_Hill'> Australia/Broken_Hill
# timezone name: Australia/Canberra - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Canberra'> Australia/Canberra
# timezone name: Australia/Currie - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Currie'> Australia/Currie
# timezone name: Australia/Darwin - current time in that time zone - 2022-02-21 14:18:38.591343+09:30
# <class 'pytz.tzfile.Australia/Darwin'> Australia/Darwin
# timezone name: Australia/Eucla - current time in that time zone - 2022-02-21 13:33:38.591343+08:45
# <class 'pytz.tzfile.Australia/Eucla'> Australia/Eucla
# timezone name: Australia/Hobart - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Hobart'> Australia/Hobart
# timezone name: Australia/LHI - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/LHI'> Australia/LHI
# timezone name: Australia/Lindeman - current time in that time zone - 2022-02-21 14:48:38.591343+10:00
# <class 'pytz.tzfile.Australia/Lindeman'> Australia/Lindeman
# timezone name: Australia/Lord_Howe - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Lord_Howe'> Australia/Lord_Howe
# timezone name: Australia/Melbourne - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Melbourne'> Australia/Melbourne
# timezone name: Australia/NSW - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/NSW'> Australia/NSW
# timezone name: Australia/North - current time in that time zone - 2022-02-21 14:18:38.591343+09:30
# <class 'pytz.tzfile.Australia/North'> Australia/North
# timezone name: Australia/Perth - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Australia/Perth'> Australia/Perth
# timezone name: Australia/Queensland - current time in that time zone - 2022-02-21 14:48:38.591343+10:00
# <class 'pytz.tzfile.Australia/Queensland'> Australia/Queensland
# timezone name: Australia/South - current time in that time zone - 2022-02-21 15:18:38.591343+10:30
# <class 'pytz.tzfile.Australia/South'> Australia/South
# timezone name: Australia/Sydney - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Sydney'> Australia/Sydney
# timezone name: Australia/Tasmania - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Tasmania'> Australia/Tasmania
# timezone name: Australia/Victoria - current time in that time zone - 2022-02-21 15:48:38.591343+11:00
# <class 'pytz.tzfile.Australia/Victoria'> Australia/Victoria
# timezone name: Australia/West - current time in that time zone - 2022-02-21 12:48:38.591343+08:00
# <class 'pytz.tzfile.Australia/West'> Australia/West
# timezone name: Australia/Yancowinna - current time in that time zone - 2022-02-21 15:18:38.591343+10:30
# <class 'pytz.tzfile.Australia/Yancowinna'> Australia/Yancowinna

# %%
import datetime as dt


print(dtt.now())
t = dt.time(4, 20, 1)

# Let's show the different components
print(t)
print('hour  :', t.hour)
print('minute:', t.minute)
print('second:', t.second)
print('microsecond:', t.microsecond)
print('tzinfo:', t.tzinfo)
# Out:
# 2022-02-21 10:23:34.498249
# 04:20:01
# hour  : 4
# minute: 20
# second: 1
# microsecond: 0
# tzinfo: None

# %% [markdown]
# ### DateTime

# %% [markdown]
# ##### able to represent both time and date details

# %%
import datetime
from datetime import datetime as dtt
print(datetime.datetime.today())
print(datetime.datetime.today().ctime())
print('tuple:', datetime.datetime.today().timetuple())
print('ordinal:', datetime.datetime.today().toordinal()) # Each day has a value of 1, starting from january 1 0001
print('Year :', datetime.datetime.today().year)
print('Month:', datetime.datetime.today().month)
print('Day  :', datetime.datetime.today().day)
print('Hour  :', datetime.datetime.today().hour)
print('Minute  :', datetime.datetime.today().minute)
print('Seconds  :', datetime.datetime.today().second)
print('MicroSecond  :', datetime.datetime.today().microsecond)
print('timezone  :', datetime.datetime.today().tzinfo)
# Out:
# 2022-02-21 10:24:15.446710
# Mon Feb 21 10:24:15 2022
# tuple: time.struct_time(tm_year=2022, tm_mon=2, tm_mday=21, tm_hour=10, tm_min=24, tm_sec=15, tm_wday=0, tm_yday=52, tm_isdst=-1)
# ordinal: 738207
# Year : 2022
# Month: 2
# Day  : 21
# Hour  : 10
# Minute  : 24
# Seconds  : 15
# MicroSecond  : 447708
# timezone  : None

# %% [markdown]
# Note: A time instance only holds values of time, and not a date associated with the time.
#
# We can also check the min and max values a time of day can have in the module:

# %%
import datetime
print('Earliest  :', datetime.time.min)
print('Latest    :', datetime.time.max)

print('Earliest  :', datetime.date.min)
print('Latest    :', datetime.date.max)


print('Resolution:', datetime.time.resolution)
# Out:
# Earliest  : 00:00:00
# Latest    : 23:59:59.999999
# Earliest  : 0001-01-01
# Latest    : 9999-12-31
# Resolution: 0:00:00.000001

# %% [markdown]
# The min and max class attributes reflect the valid range of times in a single day.

# %% [markdown]
# ## Date
# datetime (as you might suspect) also allows us to work with date timestamps. Calendar date values are represented with the date class. Instances have attributes for year, month, and day. It is easy to create a date representing today’s date using the today() class method.
#
# Let's see some examples:

# %% [markdown]
# ##### able to represent only date details

# %%
#from datetime import date
import datetime
today = datetime.date.today()
print(today)
print('ctime:', today.ctime())
print('tuple:', today.timetuple())
print('ordinal:', today.toordinal()) # Each day has a value of 1, starting from january 01 0001
print('Year :', today.year)
print('Month:', today.month)
print('Day  :', today.day)
print(datetime.date.today().hour)
# Out:
# 2022-02-22
# ctime: Tue Feb 22 00:00:00 2022
# tuple: time.struct_time(tm_year=2022, tm_mon=2, tm_mday=22, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=53, tm_isdst=-1)
# ordinal: 738208
# Year : 2022
# Month: 2
# Day  : 22
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-ea53d1613289> in <module>
#       9 print('Month:', today.month)
#      10 print('Day  :', today.day)
# ---> 11 print(datetime.date.today().hour)
#
# AttributeError: 'datetime.date' object has no attribute 'hour'

# %%
today = datetime.date.today()
print(today)
today = datetime.date(today.year, today.month, day = today.day-10)
print(today)
today = datetime.date(today.year, today.month-1, day = today.day-1)
print(today)
# Out:
# 2022-02-21
# 2022-02-11
# 2022-01-10

# %%
import time
pattern = '%d.%m.%Y %H:%M:%S:%f'
#pattern = '%H:%M:%S:%f'
current_time = datetime.datetime.now()
print("current time :", current_time)
print(type(current_time))

date_time = current_time.strftime(pattern)
print(date_time)
print(type(date_time))
print("################################")

pattern = '%d.%m.%Y %H:%M:%S:%f'
print(time.strptime(date_time, pattern))
print(type(time.strptime(date_time, pattern)))
print(time.strptime(date_time, pattern))

epoch = int(time.mktime(time.strptime(date_time, pattern)))
#epoch = int(time.mktime(time.strptime(date_time, '%S')))
#epoch = int(time.mktime(datetime.datetime.now()))
print(epoch)
# Out:
# current time : 2022-02-21 10:40:01.796527
# <class 'datetime.datetime'>
# 21.02.2022 10:40:01:796527
# <class 'str'>
# ################################
# time.struct_time(tm_year=2022, tm_mon=2, tm_mday=21, tm_hour=10, tm_min=40, tm_sec=1, tm_wday=0, tm_yday=52, tm_isdst=-1)
# <class 'time.struct_time'>
# time.struct_time(tm_year=2022, tm_mon=2, tm_mday=21, tm_hour=10, tm_min=40, tm_sec=1, tm_wday=0, tm_yday=52, tm_isdst=-1)
# 1645420201

# %%
d1 = datetime.date(2015, 3, 11)
print('d1:', d1)
print(d1.toordinal())
print("#####################################")
d2 = d1.replace(year=2014)
print('d2:', d2)
print(d2.toordinal())
print("#####################################")
d3 = d1.replace(year=2020, month=2,day=29)
print('d3:', d3)
print(d3.toordinal())
d1.replace(2020,9,30)
# Out:
# d1: 2015-03-11
# 735668
# #####################################
# d2: 2014-03-11
# 735303
# #####################################
# d3: 2020-02-29
# 737484
# datetime.date(2020, 9, 30)

# %% [markdown]
# As with time, the range of date values supported can be determined using the min and max attributes.

# %%
print('Earliest  :', datetime.date.min)
print('Latest    :', datetime.date.max)
print('Resolution:', datetime.date.resolution)
# Out:
# Earliest  : 0001-01-01
# Latest    : 9999-12-31
# Resolution: 1 day, 0:00:00
# Resolution: 0:00:00.000001

# %% [markdown]
# Another way to create new date instances uses the replace() method of an existing date. For example, you can change the year, leaving the day and month alone.

# %%
d1 = datetime.date(2021, 3, 11)
print('d1:', d1)

d2 = d1.replace(year=2022)
print('d2:', d2)


d3 = d1.replace(month=12)
print('d3:', d3)

d4 = d1.replace(day=20)
print('d4:', d4)

d5 = d1.replace(1)
print('d5:', d5)

d6 = d1.replace(1,12)
print('d6:', d6)

d7 = d1.replace(9991,12,31)
print('d7:', d7)
# Out:
# d1: 2021-03-11
# d2: 2022-03-11
# d3: 2021-12-11
# d4: 2021-03-20
# d5: 0001-03-11
# d6: 0001-12-11
# d7: 9991-12-31

# %% [markdown]
# # Arithmetic
# We can perform arithmetic on date objects to check for time differences. For example:

# %%
d1
# Out:
# datetime.date(2015, 3, 11)

# %%
d2
# Out:
# datetime.date(2014, 3, 11)

# %%
d1-d2
# Out:
# datetime.timedelta(days=-365)

# %% [markdown]
# #### time delta on datetime objects

# %%
current_datetime = datetime.datetime.now()
current_datetime
# Out:
# datetime.datetime(2022, 2, 22, 9, 58, 14, 483394)

# %%
time_old_1 = datetime.datetime(2018,10,15)
time_old_1
# Out:
# datetime.datetime(2018, 10, 15, 0, 0)

# %%
current_datetime - time_old_1
# Out:
# datetime.timedelta(days=507, seconds=37521, microseconds=233582)

# %%
print(current_datetime - time_old_1)
print((current_datetime - time_old_1).total_seconds())
print((current_datetime - time_old_1).total_seconds()/60)
print((current_datetime - time_old_1).total_seconds()/60/60)
print((current_datetime - time_old_1).total_seconds()/60/60/24)
# Out:
# 1226 days, 9:58:14.483394
# 105962294.483394
# 1766038.2413899
# 29433.970689831665
# 1226.4154454096526

# %% [markdown]
# ### Formatting Date time to different string formats in string

# %%
from datetime import datetime
print(str(datetime.now()))
print(type(datetime.now()))
print("####################################################")
print(datetime.now().strftime('%Y-%m-%d-%H %M %S %f'))
print("####################################################")
print(datetime.now().strftime('%d-%H %M %S %f'))
print("####################################################")
print(datetime.now().strftime('%H %M %S %f'))
print("####################################################")
print(datetime.now().strftime('%H$%M$%S$%f'))
print("####################################################")
# Out:
# 2020-03-05 10:26:47.310087
# <class 'datetime.datetime'>
# ####################################################
# 2020-03-05-10 26 47 310557
# ####################################################
# 05-10 26 47 310557
# ####################################################
# 10 26 47 311553
# ####################################################
# 10$26$47$311553
# ####################################################

# %%
from datetime import datetime
newtime = str(datetime.now().strftime('%Y-%m-%d-%H %M %S'))
print(newtime,"\t",type(newtime))
print("####################################################")
Previoustime = datetime.strptime('2011-11-15 07 54 38 002300','%Y-%m-%d %H %M %S %f')### provide the formatters in the same way as 
                                                                           #string datetime to parse the string
print(Previoustime,"\t",type(Previoustime))
print(type(Previoustime))
print(Previoustime.year)
print(Previoustime.month)
print(Previoustime.day)
print(Previoustime.hour)
print(Previoustime.minute)
print(Previoustime.second)
print(Previoustime.microsecond)
print("####################################################")

newtime1 = datetime.strptime(newtime,'%Y-%m-%d-%H %M %S')
print(newtime1)
# Out:
# 2022-02-22-10 00 11 	 <class 'str'>
# ####################################################
# 2011-11-15 07:54:38.002300 	 <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# 2011
# 11
# 15
# 7
# 54
# 38
# 2300
# ####################################################
# 2022-02-22 10:00:11

# %%
################################################
print("#######################Calculating time difference #############################")
timedifference = newtime1 - Previoustime
print(timedifference, type(timedifference))
secstime = (newtime1 - Previoustime).total_seconds()
print("total seconds", secstime)
totalminutes = secstime /60
# total timedifference between two timestamps in seconds, gives us the uptime between previous ping and current ping 
print("total minutes",totalminutes)
totalhours = totalminutes /60
print("total hours",totalhours)
totaldays = totalhours /24
print("total days",totaldays)
# Out:
# #######################Calculating time difference #############################
# 3033 days, 2:33:37.997700 <class 'datetime.timedelta'>
# total seconds 262060417.9977
# total minutes 4367673.6332950005
# total hours 72794.56055491668
# total days 3033.106689788195

# %%
from datetime import datetime
def datetimediffsecs(oldtime):
    newtime = str(datetime.now().strftime('%Y-%m-%d %H %M %S'))
    Previoustime = datetime.strptime(str(oldtime), '%Y-%m-%d %H:%M:%S.%f')
    Currenttime = datetime.strptime(newtime, '%Y-%m-%d %H %M %S')
    secstime = (Currenttime - Previoustime).total_seconds()  # total timedifference between two timestamps in seconds, gives us the uptime between previous ping and current ping 
    return secstime
print(datetime.now())
print(datetimediffsecs(datetime.now()))
# Out:
# 2022-02-22 10:03:17.709682
# -0.709682

# %% [markdown]
# This gives us the difference in days between the two dates. You can use the timedelta method to specify various units of times (days, minutes, hours, etc.)
#
# Great! You should now have a basic understanding of how to use datetime with Python to work with timestamps in your code!
