# %%
pip install mssql
# Out:
# Collecting mssql
#   Downloading mssql-1.0.1-py3-none-any.whl (3.7 kB)
# Collecting pyodbc
#   Downloading pyodbc-4.0.32-cp39-cp39-win_amd64.whl (72 kB)
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.32-cp39-cp39-win_amd64.whl (1.6 MB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.2-cp39-cp39-win_amd64.whl (101 kB)
# Installing collected packages: greenlet, sqlalchemy, pyodbc, mssql
# Successfully installed greenlet-1.1.2 mssql-1.0.1 pyodbc-4.0.32 sqlalchemy-1.4.32
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.0.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install SQLAlchemy
# Out:
# Requirement already satisfied: SQLAlchemy in c:\python39\lib\site-packages (1.4.32)
# Requirement already satisfied: greenlet!=0.4.17 in c:\python39\lib\site-packages (from SQLAlchemy) (1.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.0.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '1.4.32'

# %%
sqlalchemy.__dict__
# Out:
# {'__name__': 'sqlalchemy',
#  '__doc__': None,
#  '__package__': 'sqlalchemy',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x1bed373a160>,
#  '__spec__': ModuleSpec(name='sqlalchemy', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001BED373A160>, origin='c:\\python39\\lib\\site-packages\\sqlalchemy\\__init__.py', submodule_search_locations=['c:\\python39\\lib\\site-packages\\sqlalchemy']),
#  '__path__': ['c:\\python39\\lib\\site-packages\\sqlalchemy'],
#  '__file__': 'c:\\python39\\lib\\site-packages\\sqlalchemy\\__init__.py',
#  '__cached__': 'c:\\python39\\lib\\site-packages\\sqlalchemy\\__pycache__\\__init__.cpython-39.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#   '__build_class__': <function __build_class__>,
#   '__import__': <function __import__>,
#   'abs': <function abs(x, /)>,
#   'all': <function all(iterable, /)>,
#   'any': <function any(iterable, /)>,
#   'ascii': <function ascii(obj, /)>,
#   'bin': <function bin(number, /)>,
#   'breakpoint': <function breakpoint>,
#   'callable': <function callable(obj, /)>,
#   'chr': <function chr(i, /)>,
#   'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#   'delattr': <function delattr(obj, name, /)>,
#   'dir': <function dir>,
#   'divmod': <function divmod(x, y, /)>,
#   'eval': <function eval(source, globals=None, locals=None, /)>,
#   'exec': <function exec(source, globals=None, locals=None, /)>,
#   'format': <function format(value, format_spec='', /)>,
#   'getattr': <function getattr>,
#   'globals': <function globals()>,
#   'hasattr': <function hasattr(obj, name, /)>,
#   'hash': <function hash(obj, /)>,
#   'hex': <function hex(number, /)>,
#   'id': <function id(obj, /)>,
#   'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001BED36BCCA0>>,
#   'isinstance': <function isinstance(obj, class_or_tuple, /)>,
#   'issubclass': <function issubclass(cls, class_or_tuple, /)>,
#   'iter': <function iter>,
#   'len': <function len(obj, /)>,
#   'locals': <function locals()>,
#   'max': <function max>,
#   'min': <function min>,
#   'next': <function next>,
#   'oct': <function oct(number, /)>,
#   'ord': <function ord(c, /)>,
#   'pow': <function pow(base, exp, mod=None)>,
#   'print': <function print>,
#   'repr': <function repr(obj, /)>,
#   'round': <function round(number, ndigits=None)>,
#   'setattr': <function setattr(obj, name, value, /)>,
#   'sorted': <function sorted(iterable, /, *, key=None, reverse=False)>,
#   'sum': <function sum(iterable, /, start=0)>,
#   'vars': <function vars>,
#   'None': None,
#   'Ellipsis': Ellipsis,
#   'NotImplemented': NotImplemented,
#   'False': False,
#   'True': True,
#   'bool': bool,
#   'memoryview': memoryview,
#   'bytearray': bytearray,
#   'bytes': bytes,
#   'classmethod': classmethod,
#   'complex': complex,
#   'dict': dict,
#   'enumerate': enumerate,
#   'filter': filter,
#   'float': float,
#   'frozenset': frozenset,
#   'property': property,
#   'int': int,
#   'list': list,
#   'map': map,
#   'object': object,
#   'range': range,
#   'reversed': reversed,
#   'set': set,
#   'slice': slice,
#   'staticmethod': staticmethod,
#   'str': str,
#   'super': super,
#   'tuple': tuple,
#   'type': type,
#   'zip': zip,
#   '__debug__': True,
#   'BaseException': BaseException,
#   'Exception': Exception,
#   'TypeError': TypeError,
#   'StopAsyncIteration': StopAsyncIteration,
#   'StopIteration': StopIteration,
#   'GeneratorExit': GeneratorExit,
#   'SystemExit': SystemExit,
#   'KeyboardInterrupt': KeyboardInterrupt,
#   'ImportError': ImportError,
#   'ModuleNotFoundError': ModuleNotFoundError,
#   'OSError': OSError,
#   'EnvironmentError': OSError,
#   'IOError': OSError,
#   'WindowsError': OSError,
#   'EOFError': EOFError,
#   'RuntimeError': RuntimeError,
#   'RecursionError': RecursionError,
#   'NotImplementedError': NotImplementedError,
#   'NameError': NameError,
#   'UnboundLocalError': UnboundLocalError,
#   'AttributeError': AttributeError,
#   'SyntaxError': SyntaxError,
#   'IndentationError': IndentationError,
#   'TabError': TabError,
#   'LookupError': LookupError,
#   'IndexError': IndexError,
#   'KeyError': KeyError,
#   'ValueError': ValueError,
#   'UnicodeError': UnicodeError,
#   'UnicodeEncodeError': UnicodeEncodeError,
#   'UnicodeDecodeError': UnicodeDecodeError,
#   'UnicodeTranslateError': UnicodeTranslateError,
#   'AssertionError': AssertionError,
#   'ArithmeticError': ArithmeticError,
#   'FloatingPointError': FloatingPointError,
#   'OverflowError': OverflowError,
#   'ZeroDivisionError': ZeroDivisionError,
#   'SystemError': SystemError,
#   'ReferenceError': ReferenceError,
#   'MemoryError': MemoryError,
#   'BufferError': BufferError,
#   'Warning': Warning,
#   'UserWarning': UserWarning,
#   'DeprecationWarning': DeprecationWarning,
#   'PendingDeprecationWarning': PendingDeprecationWarning,
#   'SyntaxWarning': SyntaxWarning,
#   'RuntimeWarning': RuntimeWarning,
#   'FutureWarning': FutureWarning,
#   'ImportWarning': ImportWarning,
#   'UnicodeWarning': UnicodeWarning,
#   'BytesWarning': BytesWarning,
#   'ResourceWarning': ResourceWarning,
#   'ConnectionError': ConnectionError,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
#   'ChildProcessError': ChildProcessError,
#   'ConnectionAbortedError': ConnectionAbortedError,
#   'ConnectionRefusedError': ConnectionRefusedError,
#   'ConnectionResetError': ConnectionResetError,
#   'FileExistsError': FileExistsError,
#   'FileNotFoundError': FileNotFoundError,
#   'IsADirectoryError': IsADirectoryError,
#   'NotADirectoryError': NotADirectoryError,
#   'InterruptedError': InterruptedError,
#   'PermissionError': PermissionError,
#   'ProcessLookupError': ProcessLookupError,
#   'TimeoutError': TimeoutError,
#   'open': <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#   'copyright': Copyright (c) 2001-2020 Python Software Foundation.
#   All Rights Reserved.
#
#   Copyright (c) 2000 BeOpen.com.
#   All Rights Reserved.
#
#   Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#   All Rights Reserved.
#
#   Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#   All Rights Reserved.,
#   'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#       for supporting Python development.  See www.python.org for more information.,
#   'license': Type license() to see the full license text,
#   'help': Type help() for interactive help, or help(object) for help about object.,
#   '__IPYTHON__': True,
#   'display': <function IPython.core.display.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, **kwargs)>,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001BED36BCC10>>},
#  'cimmutabledict': <module 'sqlalchemy.cimmutabledict' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\cimmutabledict.cp39-win_amd64.pyd'>,
#  'exc': <module 'sqlalchemy.exc' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\exc.py'>,
#  'util': <module 'sqlalchemy.util' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\util\\__init__.py'>,
#  '_util': <module 'sqlalchemy.util' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\util\\__init__.py'>,
#  'inspection': <module 'sqlalchemy.inspection' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\inspection.py'>,
#  'event': <module 'sqlalchemy.event' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\event\\__init__.py'>,
#  'cprocessors': <module 'sqlalchemy.cprocessors' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\cprocessors.cp39-win_amd64.pyd'>,
#  'processors': <module 'sqlalchemy.processors' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\processors.py'>,
#  'types': <module 'sqlalchemy.types' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\types.py'>,
#  'sql': <module 'sqlalchemy.sql' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\sql\\__init__.py'>,
#  'log': <module 'sqlalchemy.log' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\log.py'>,
#  'dialects': <module 'sqlalchemy.dialects' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\dialects\\__init__.py'>,
#  'pool': <module 'sqlalchemy.pool' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\pool\\__init__.py'>,
#  'cresultproxy': <module 'sqlalchemy.cresultproxy' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\cresultproxy.cp39-win_amd64.pyd'>,
#  'engine': <module 'sqlalchemy.engine' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\engine\\__init__.py'>,
#  'create_engine': <function sqlalchemy.engine.create.create_engine(url, **kwargs)>,
#  'create_mock_engine': <function sqlalchemy.engine.mock.create_mock_engine(url, executor, **kw)>,
#  'engine_from_config': <function sqlalchemy.engine.create.engine_from_config(configuration, prefix='sqlalchemy.', **kwargs)>,
#  'inspect': <function sqlalchemy.inspection.inspect(subject, raiseerr=True)>,
#  'schema': <module 'sqlalchemy.schema' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\schema.py'>,
#  'BLANK_SCHEMA': symbol('blank_schema'),
#  'CheckConstraint': sqlalchemy.sql.schema.CheckConstraint,
#  'Column': sqlalchemy.sql.schema.Column,
#  'ColumnDefault': sqlalchemy.sql.schema.ColumnDefault,
#  'Computed': sqlalchemy.sql.schema.Computed,
#  'Constraint': sqlalchemy.sql.schema.Constraint,
#  'DDL': sqlalchemy.sql.ddl.DDL,
#  'DefaultClause': sqlalchemy.sql.schema.DefaultClause,
#  'FetchedValue': sqlalchemy.sql.schema.FetchedValue,
#  'ForeignKey': sqlalchemy.sql.schema.ForeignKey,
#  'ForeignKeyConstraint': sqlalchemy.sql.schema.ForeignKeyConstraint,
#  'Identity': sqlalchemy.sql.schema.Identity,
#  'Index': sqlalchemy.sql.schema.Index,
#  'MetaData': sqlalchemy.sql.schema.MetaData,
#  'PrimaryKeyConstraint': sqlalchemy.sql.schema.PrimaryKeyConstraint,
#  'Sequence': sqlalchemy.sql.schema.Sequence,
#  'Table': sqlalchemy.sql.schema.Table,
#  'ThreadLocalMetaData': sqlalchemy.sql.schema.ThreadLocalMetaData,
#  'UniqueConstraint': sqlalchemy.sql.schema.UniqueConstraint,
#  'alias': <function sqlalchemy.sql.expression.alias(selectable, name=None, flat=False)>,
#  'all_': <function sqlalchemy.sql.expression.all_(expr)>,
#  'and_': <function sqlalchemy.sql.expression.and_(*clauses)>,
#  'any_': <function sqlalchemy.sql.expression.any_(expr)>,
#  'asc': <function sqlalchemy.sql.expression.asc(column)>,
#  'between': <function sqlalchemy.sql.elements.between(expr, lower_bound, upper_bound, symmetric=False)>,
#  'bindparam': <function sqlalchemy.sql.expression.bindparam(key, value=symbol('NO_ARG'), type_=None, unique=False, required=symbol('NO_ARG'), quote=None, callable_=None, expanding=False, isoutparam=False, literal_execute=False, _compared_to_operator=None, _compared_to_type=None, _is_crud=False)>,
#  'case': <function sqlalchemy.sql.expression.case(*whens, **kw)>,
#  'cast': <function sqlalchemy.sql.expression.cast(expression, type_)>,
#  'collate': <function sqlalchemy.sql.elements.collate(expression, collation)>,
#  'column': <function sqlalchemy.sql.expression.column(text, type_=None, is_literal=False, _selectable=None)>,
#  'delete': <function sqlalchemy.sql.expression.delete(table, whereclause=None, bind=None, returning=None, prefixes=None, **dialect_kw)>,
#  'desc': <function sqlalchemy.sql.expression.desc(column)>,
#  'distinct': <function sqlalchemy.sql.expression.distinct(expr)>,
#  'except_': <function sqlalchemy.sql.expression.except_(*selects, **kwargs)>,
#  'except_all': <function sqlalchemy.sql.expression.except_all(*selects, **kwargs)>,
#  'exists': <function sqlalchemy.sql.expression.exists(*args, **kwargs)>,
#  'extract': <function sqlalchemy.sql.expression.extract(field, expr, **kwargs)>,
#  'false': <function sqlalchemy.sql.expression.false()>,
#  'func': <sqlalchemy.sql.functions._FunctionGenerator at 0x1bed3bfc2e0>,
#  'funcfilter': <function sqlalchemy.sql.expression.funcfilter(func, *criterion)>,
#  'insert': <function sqlalchemy.sql.expression.insert(table, values=None, inline=False, bind=None, prefixes=None, returning=None, return_defaults=False, **dialect_kw)>,
#  'intersect': <function sqlalchemy.sql.expression.intersect(*selects, **kwargs)>,
#  'intersect_all': <function sqlalchemy.sql.expression.intersect_all(*selects, **kwargs)>,
#  'join': <function sqlalchemy.sql.expression.join(left, right, onclause=None, isouter=False, full=False)>,
#  'LABEL_STYLE_DEFAULT': symbol('LABEL_STYLE_DISAMBIGUATE_ONLY'),
#  'LABEL_STYLE_DISAMBIGUATE_ONLY': symbol('LABEL_STYLE_DISAMBIGUATE_ONLY'),
#  'LABEL_STYLE_NONE': symbol('LABEL_STYLE_NONE'),
#  'LABEL_STYLE_TABLENAME_PLUS_COL': symbol('LABEL_STYLE_TABLENAME_PLUS_COL'),
#  'lambda_stmt': <function sqlalchemy.sql.lambdas.lambda_stmt(lmb, enable_tracking=True, track_closure_variables=True, track_on=None, global_track_bound_values=True, track_bound_values=True, lambda_cache=None)>,
#  'lateral': <function sqlalchemy.sql.expression.lateral(selectable, name=None)>,
#  'literal': <function sqlalchemy.sql.elements.literal(value, type_=None)>,
#  'literal_column': <function sqlalchemy.sql.elements.literal_column(text, type_=None)>,
#  'modifier': <sqlalchemy.sql.functions._FunctionGenerator at 0x1bed3c0e130>,
#  'not_': <function sqlalchemy.sql.elements.not_(clause)>,
#  'null': <function sqlalchemy.sql.expression.null()>,
#  'nulls_first': <function sqlalchemy.sql.expression.nulls_first(column)>,
#  'nulls_last': <function sqlalchemy.sql.expression.nulls_last(column)>,
#  'nullsfirst': <function sqlalchemy.sql.expression.nulls_first(column)>,
#  'nullslast': <function sqlalchemy.sql.expression.nulls_last(column)>,
#  'or_': <function sqlalchemy.sql.expression.or_(*clauses)>,
#  'outerjoin': <function sqlalchemy.sql.expression.outerjoin(left, right, onclause=None, full=False)>,
#  'outparam': <function sqlalchemy.sql.elements.outparam(key, type_=None)>,
#  'over': <function sqlalchemy.sql.expression.over(element, partition_by=None, order_by=None, range_=None, rows=None)>,
#  'select': <function sqlalchemy.sql.expression.select(*args, **kw)>,
#  'subquery': <function sqlalchemy.sql.selectable.subquery(alias, *args, **kwargs)>,
#  'table': <function sqlalchemy.sql.expression.table(name, *columns, **kw)>,
#  'tablesample': <function sqlalchemy.sql.expression.tablesample(selectable, sampling, name=None, seed=None)>,
#  'text': <function sqlalchemy.sql.expression.text(text, bind=None)>,
#  'true': <function sqlalchemy.sql.expression.true()>,
#  'tuple_': <function sqlalchemy.sql.expression.tuple_(*clauses, **kw)>,
#  'type_coerce': <function sqlalchemy.sql.expression.type_coerce(expression, type_)>,
#  'union': <function sqlalchemy.sql.expression.union(*selects, **kwargs)>,
#  'union_all': <function sqlalchemy.sql.expression.union_all(*selects, **kwargs)>,
#  'update': <function sqlalchemy.sql.expression.update(table, whereclause=None, values=None, inline=False, bind=None, prefixes=None, returning=None, return_defaults=False, preserve_parameter_order=False, **dialect_kw)>,
#  'values': <function sqlalchemy.sql.expression.values(*columns, **kw)>,
#  'within_group': <function sqlalchemy.sql.expression.within_group(element, *order_by)>,
#  'ARRAY': sqlalchemy.sql.sqltypes.ARRAY,
#  'BIGINT': sqlalchemy.sql.sqltypes.BIGINT,
#  'BigInteger': sqlalchemy.sql.sqltypes.BigInteger,
#  'BINARY': sqlalchemy.sql.sqltypes.BINARY,
#  'BLOB': sqlalchemy.sql.sqltypes.BLOB,
#  'BOOLEAN': sqlalchemy.sql.sqltypes.BOOLEAN,
#  'Boolean': sqlalchemy.sql.sqltypes.Boolean,
#  'CHAR': sqlalchemy.sql.sqltypes.CHAR,
#  'CLOB': sqlalchemy.sql.sqltypes.CLOB,
#  'DATE': sqlalchemy.sql.sqltypes.DATE,
#  'Date': sqlalchemy.sql.sqltypes.Date,
#  'DATETIME': sqlalchemy.sql.sqltypes.DATETIME,
#  'DateTime': sqlalchemy.sql.sqltypes.DateTime,
#  'DECIMAL': sqlalchemy.sql.sqltypes.DECIMAL,
#  'Enum': sqlalchemy.sql.sqltypes.Enum,
#  'FLOAT': sqlalchemy.sql.sqltypes.FLOAT,
#  'Float': sqlalchemy.sql.sqltypes.Float,
#  'INT': sqlalchemy.sql.sqltypes.INTEGER,
#  'INTEGER': sqlalchemy.sql.sqltypes.INTEGER,
#  'Integer': sqlalchemy.sql.sqltypes.Integer,
#  'Interval': sqlalchemy.sql.sqltypes.Interval,
#  'JSON': sqlalchemy.sql.sqltypes.JSON,
#  'LargeBinary': sqlalchemy.sql.sqltypes.LargeBinary,
#  'NCHAR': sqlalchemy.sql.sqltypes.NCHAR,
#  'NUMERIC': sqlalchemy.sql.sqltypes.NUMERIC,
#  'Numeric': sqlalchemy.sql.sqltypes.Numeric,
#  'NVARCHAR': sqlalchemy.sql.sqltypes.NVARCHAR,
#  'PickleType': sqlalchemy.sql.sqltypes.PickleType,
#  'REAL': sqlalchemy.sql.sqltypes.REAL,
#  'SMALLINT': sqlalchemy.sql.sqltypes.SMALLINT,
#  'SmallInteger': sqlalchemy.sql.sqltypes.SmallInteger,
#  'String': sqlalchemy.sql.sqltypes.String,
#  'TEXT': sqlalchemy.sql.sqltypes.TEXT,
#  'Text': sqlalchemy.sql.sqltypes.Text,
#  'TIME': sqlalchemy.sql.sqltypes.TIME,
#  'Time': sqlalchemy.sql.sqltypes.Time,
#  'TIMESTAMP': sqlalchemy.sql.sqltypes.TIMESTAMP,
#  'TupleType': sqlalchemy.sql.sqltypes.TupleType,
#  'TypeDecorator': sqlalchemy.sql.type_api.TypeDecorator,
#  'Unicode': sqlalchemy.sql.sqltypes.Unicode,
#  'UnicodeText': sqlalchemy.sql.sqltypes.UnicodeText,
#  'VARBINARY': sqlalchemy.sql.sqltypes.VARBINARY,
#  'VARCHAR': sqlalchemy.sql.sqltypes.VARCHAR,
#  '__version__': '1.4.32',
#  '__go': <function sqlalchemy.__go(lcls)>,
#  'events': <module 'sqlalchemy.events' from 'c:\\python39\\lib\\site-packages\\sqlalchemy\\events.py'>,
#  '__all__': ['ARRAY',
#   'BIGINT',
#   'BINARY',
#   'BLANK_SCHEMA',
#   'BLOB',
#   'BOOLEAN',
#   'BigInteger',
#   'Boolean',
#   'CHAR',
#   'CLOB',
#   'CheckConstraint',
#   'Column',
#   'ColumnDefault',
#   'Computed',
#   'Constraint',
#   'DATE',
#   'DATETIME',
#   'DDL',
#   'DECIMAL',
#   'Date',
#   'DateTime',
#   'DefaultClause',
#   'Enum',
#   'FLOAT',
#   'FetchedValue',
#   'Float',
#   'ForeignKey',
#   'ForeignKeyConstraint',
#   'INT',
#   'INTEGER',
#   'Identity',
#   'Index',
#   'Integer',
#   'Interval',
#   'JSON',
#   'LABEL_STYLE_DEFAULT',
#   'LABEL_STYLE_DISAMBIGUATE_ONLY',
#   'LABEL_STYLE_NONE',
#   'LABEL_STYLE_TABLENAME_PLUS_COL',
#   'LargeBinary',
#   'MetaData',
#   'NCHAR',
#   'NUMERIC',
#   'NVARCHAR',
#   'Numeric',
#   'PickleType',
#   'PrimaryKeyConstraint',
#   'REAL',
#   'SMALLINT',
#   'Sequence',
#   'SmallInteger',
#   'String',
#   'TEXT',
#   'TIME',
#   'TIMESTAMP',
#   'Table',
#   'Text',
#   'ThreadLocalMetaData',
#   'Time',
#   'TupleType',
#   'TypeDecorator',
#   'Unicode',
#   'UnicodeText',
#   'UniqueConstraint',
#   'VARBINARY',
#   'VARCHAR',
#   'alias',
#   'all_',
#   'and_',
#   'any_',
#   'asc',
#   'between',
#   'bindparam',
#   'case',
#   'cast',
#   'collate',
#   'column',
#   'create_engine',
#   'create_mock_engine',
#   'delete',
#   'desc',
#   'distinct',
#   'engine_from_config',
#   'except_',
#   'except_all',
#   'exists',
#   'extract',
#   'false',
#   'func',
#   'funcfilter',
#   'insert',
#   'inspect',
#   'intersect',
#   'intersect_all',
#   'join',
#   'lambda_stmt',
#   'lateral',
#   'literal',
#   'literal_column',
#   'modifier',
#   'not_',
#   'null',
#   'nulls_first',
#   'nulls_last',
#   'nullsfirst',
#   'nullslast',
#   'or_',
#   'outerjoin',
#   'outparam',
#   'over',
#   'select',
#   'subquery',
#   'table',
#   'tablesample',
#   'text',
#   'true',
#   'tuple_',
#   'type_coerce',
#   'union',
#   'union_all',
#   'update',
#   'values',
#   'within_group']}

# %%
from sqlalchemy import create_engine
engine = create_engine("sqlite+pysqlite:///:memory:", echo=True, future=True)

# %%
from sqlalchemy import text
with engine.connect() as conn:
    result = conn.execute(text("select 'hello world'"))
    print(result.all())
# Out:
# 2022-03-24 12:00:59,434 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-03-24 12:00:59,435 INFO sqlalchemy.engine.Engine select 'hello world'
# 2022-03-24 12:00:59,436 INFO sqlalchemy.engine.Engine [generated in 0.00218s] ()
# [('hello world',)]
# 2022-03-24 12:00:59,437 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# #### using pandas

# %%
import pandas as pd
from sqlalchemy import create_engine

def process_sql_using_pandas():
    engine = create_engine(
        "postgresql://postgres:pass@localhost/example"
    )
    dataframe = pd.read_sql("SELECT * FROM users", engine)
    print(f"Got dataframe with {len(dataframe)} entries")
    # ... do something with dataframe ...


if __name__ == '__main__':
    process_sql_using_pandas()

# %% [markdown]
# #### using chunk size

# %%
import pandas as pd
from sqlalchemy import create_engine

def process_sql_using_pandas():
    engine = create_engine(
        "postgresql://postgres:pass@localhost/example"
    )
    for chunk_dataframe in pd.read_sql(
            "SELECT * FROM users", engine, chunksize=1000):
        print(
            f"Got dataframe w/{len(chunk_dataframe)} rows"
        )
        # ... do something with dataframe ...

if __name__ == '__main__':
    process_sql_using_pandas()
